# %%
import os
import random
import pickle
from collections import defaultdict, Counter
import mido
from mido import MidiFile, MidiTrack, Message
import glob

class SymbolicMusicGenerator:
    def __init__(self):
        self.trigram_model = defaultdict(Counter)
        self.harmony_model = defaultdict(Counter)  # For harmonization
        self.melody_model = defaultdict(Counter)   # For melody generation
        self.chord_progressions = defaultdict(Counter)  # For chord-based generation
        self.tempo_transitions = defaultdict(list)
        self.note_durations = defaultdict(list)
        self.velocity_patterns = defaultdict(list)
        self.time_signatures = []
        self.tempos = []
        
    def extract_musical_events(self, midi_file_path):
        """Extract musical events from a MIDI file including timing information"""
        try:
            mid = MidiFile(midi_file_path)
            events = []
            current_tempo = 500000  # Default tempo (120 BPM)
            current_time = 0
            
            # Track active notes for duration calculation and harmony analysis
            active_notes = {}
            simultaneous_notes = defaultdict(list)  # For harmony extraction
            
            for track in mid.tracks:
                track_time = 0
                for msg in track:
                    track_time += msg.time
                    current_time = track_time
                    
                    if msg.type == 'set_tempo':
                        current_tempo = msg.tempo
                        events.append(('tempo', msg.tempo, current_time))
                        
                    elif msg.type == 'time_signature':
                        events.append(('time_sig', f"{msg.numerator}/{msg.denominator}", current_time))
                        
                    elif msg.type == 'note_on' and msg.velocity > 0:
                        note_key = (msg.channel, msg.note)
                        active_notes[note_key] = {
                            'start_time': current_time,
                            'velocity': msg.velocity,
                            'tempo': current_tempo
                        }
                        # Group notes by time windows for harmony analysis
                        time_window = current_time // 240  # 240 ticks = eighth note window
                        simultaneous_notes[time_window].append(msg.note)
                        
                        events.append(('note_on', msg.note, current_time, msg.velocity, current_tempo))
                        
                    elif msg.type == 'note_off' or (msg.type == 'note_on' and msg.velocity == 0):
                        note_key = (msg.channel, msg.note)
                        if note_key in active_notes:
                            note_info = active_notes[note_key]
                            duration = current_time - note_info['start_time']
                            events.append(('note_off', msg.note, current_time, duration, note_info['velocity']))
                            del active_notes[note_key]
            
            # Store harmony information for conditional generation
            self._extract_harmonies(simultaneous_notes)
            
            return events
            
        except Exception as e:
            print(f"Error processing {midi_file_path}: {e}")
            return []
    
    def _extract_harmonies(self, simultaneous_notes):
        """Extract harmony patterns from simultaneous notes"""
        for time_window, notes in simultaneous_notes.items():
            if len(notes) >= 2:  # At least 2 notes for harmony
                # Sort notes and create chord representation
                sorted_notes = sorted(set(notes))  # Remove duplicates and sort
                if len(sorted_notes) >= 2:
                    # Create melody-harmony pairs (lowest note as melody, others as harmony)
                    melody_note = sorted_notes[0] % 12  # Pitch class of lowest note
                    harmony_notes = [n % 12 for n in sorted_notes[1:]]  # Pitch classes of harmony
                    
                    # Store melody -> harmony mapping
                    harmony_key = f"M{melody_note}"
                    harmony_value = "_".join([f"H{h}" for h in sorted(harmony_notes)])
                    self.harmony_model[harmony_key][harmony_value] += 1
                    
                    # Store harmony -> melody mapping (for melody generation from chords)
                    if len(harmony_notes) >= 2:  # At least 2 harmony notes
                        chord_key = "_".join([f"C{h}" for h in sorted(harmony_notes)])
                        melody_value = f"M{melody_note}"
                        self.melody_model[chord_key][melody_value] += 1
    
    def _notes_to_chord_symbol(self, notes):
        """Convert a list of notes to a simplified chord symbol"""
        if not notes:
            return "REST"
        
        # Convert to pitch classes and sort
        pitch_classes = sorted(set([n % 12 for n in notes]))
        
        if len(pitch_classes) == 1:
            return f"SINGLE_{pitch_classes[0]}"
        elif len(pitch_classes) == 2:
            interval = (pitch_classes[1] - pitch_classes[0]) % 12
            return f"INT_{pitch_classes[0]}_{interval}"
        else:
            # Simple chord classification
            root = pitch_classes[0]
            intervals = [(pc - root) % 12 for pc in pitch_classes[1:]]
            intervals_str = "_".join(map(str, sorted(intervals)))
            return f"CHORD_{root}_{intervals_str}"
    def create_symbolic_representation(self, events):
        """Convert events to symbolic representation for Markov chain"""
        symbols = []
        prev_time = 0
        
        # Filter and sort note events
        note_events = [(e[2], e) for e in events if e[0] == 'note_on']
        note_events.sort()  # Sort by time
        
        for time_pos, event in note_events:
            note = event[1]
            velocity = event[3]
            tempo = event[4]
            
            # Calculate time delta from previous note
            time_delta = max(0, time_pos - prev_time)
            prev_time = time_pos
            
            # Quantize timing to musical values (in ticks)
            if time_delta < 120:
                timing = "T1"  # Very short
            elif time_delta < 240:
                timing = "T2"  # Eighth note
            elif time_delta < 480:
                timing = "T3"  # Quarter note
            elif time_delta < 960:
                timing = "T4"  # Half note
            else:
                timing = "T5"  # Whole note or longer
            
            # Quantize velocity more musically
            if velocity < 40:
                vel_level = "pp"  # pianissimo
            elif velocity < 70:
                vel_level = "mp"  # mezzo-piano  
            elif velocity < 90:
                vel_level = "mf"  # mezzo-forte
            elif velocity < 110:
                vel_level = "f"   # forte
            else:
                vel_level = "ff"  # fortissimo
            
            # Use pitch classes and octaves for better musical coherence
            pitch_class = note % 12
            octave = note // 12
            
            # Create more musical symbol
            symbol = f"P{pitch_class}_O{octave}_{vel_level}_{timing}"
            symbols.append(symbol)
                
        return symbols
    
    def build_trigram_model(self, symbols):
        """Build trigram Markov chain from symbols"""
        for i in range(len(symbols) - 2):
            trigram_key = (symbols[i], symbols[i + 1])
            next_symbol = symbols[i + 2]
            self.trigram_model[trigram_key][next_symbol] += 1
    
    def train_on_dataset(self, dataset_path, max_files=50):
        """Train the model on MIDI files from the dataset"""
        print("Scanning for MIDI files...")
        midi_files = []
        
        # Recursively find all .mid files
        for root, dirs, files in os.walk(dataset_path):
            for file in files:
                if file.lower().endswith(('.mid', '.midi')):
                    midi_files.append(os.path.join(root, file))
        
        print(f"Found {len(midi_files)} MIDI files")
        
        # Limit the number of files to process for reasonable training time
        if len(midi_files) > max_files:
            midi_files = random.sample(midi_files, max_files)
            print(f"Processing {max_files} randomly selected files")
        
        processed_count = 0
        total_notes = 0
        octave_distribution = defaultdict(int)
        
        for midi_file in midi_files:
            print(f"Processing: {os.path.basename(midi_file)} ({processed_count + 1}/{len(midi_files)})")
            
            events = self.extract_musical_events(midi_file)
            if events:
                symbols = self.create_symbolic_representation(events)
                if len(symbols) > 10:  # Only use files with sufficient content
                    self.build_trigram_model(symbols)
                    
                    # Debug: track octave distribution
                    for symbol in symbols:
                        if symbol.startswith('P'):
                            try:
                                parts = symbol.split('_')
                                octave = int(parts[1][1:])
                                octave_distribution[octave] += 1
                                total_notes += 1
                            except:
                                pass
                    
                    # Store additional musical information
                    tempos = [e[1] for e in events if e[0] == 'tempo']
                    if tempos:
                        self.tempos.extend(tempos)
                        
                processed_count += 1
        
        print(f"Training completed on {processed_count} files")
        print(f"Learned {len(self.trigram_model)} trigram patterns")
        print(f"Total notes processed: {total_notes}")
        print("Octave distribution in training data:")
        for octave in sorted(octave_distribution.keys()):
            percentage = (octave_distribution[octave] / total_notes) * 100
            print(f"  Octave {octave}: {octave_distribution[octave]} notes ({percentage:.1f}%)")
    
    def generate_sequence(self, length=200, seed=None):
        """Generate a new sequence using the trigram model"""
        if len(self.trigram_model) == 0:
            raise ValueError("Model not trained yet!")
        
        # Start with a random trigram or use seed
        if seed and len(seed) >= 2:
            current_bigram = (seed[0], seed[1])
        else:
            current_bigram = random.choice(list(self.trigram_model.keys()))
        
        sequence = list(current_bigram)
        
        # Track musical context for better generation
        last_pitch_class = None
        last_octave = None
        octave_bias = 0  # Bias to encourage higher octaves
        
        for i in range(length - 2):
            if current_bigram in self.trigram_model:
                # Choose next symbol based on probability distribution
                next_symbols = self.trigram_model[current_bigram]
                total_count = sum(next_symbols.values())
                
                if total_count > 0:
                    # Create weighted list for better selection
                    weighted_choices = []
                    for symbol, count in next_symbols.items():
                        # Add some musical intelligence - prefer steps and skips
                        weight = count
                        if symbol.startswith('P') and last_pitch_class is not None:
                            try:
                                parts = symbol.split('_')
                                pitch_class = int(parts[0][1:])
                                octave = int(parts[1][1:])
                                
                                # Strongly favor higher octaves
                                if octave >= 5:
                                    weight = int(weight * 2.0)
                                elif octave >= 4:
                                    weight = int(weight * 1.5)
                                elif octave <= 2:
                                    weight = max(1, int(weight * 0.3))  # Heavily discourage low octaves
                                
                                # Slightly favor melodic intervals (steps and small skips)
                                interval = abs(pitch_class - last_pitch_class)
                                if interval <= 2 or interval >= 10:  # Steps (including octave wrapping)
                                    weight = int(weight * 1.2)
                                elif interval <= 4 or interval >= 8:  # Small skips
                                    weight = int(weight * 1.1)
                                
                                # Favor staying in similar octave range
                                if abs(octave - last_octave) <= 1:
                                    weight = int(weight * 1.1)
                                    
                                last_pitch_class = pitch_class
                                last_octave = octave
                            except:
                                pass
                        
                        weighted_choices.extend([symbol] * max(1, weight))
                    
                    if weighted_choices:
                        next_symbol = random.choice(weighted_choices)
                        sequence.append(next_symbol)
                        current_bigram = (current_bigram[1], next_symbol)
                    else:
                        # Fallback
                        current_bigram = random.choice(list(self.trigram_model.keys()))
                        sequence.extend(current_bigram)
                else:
                    # Fallback to random trigram
                    current_bigram = random.choice(list(self.trigram_model.keys()))
                    sequence.extend(current_bigram)
            else:
                # Start new random trigram
                current_bigram = random.choice(list(self.trigram_model.keys()))
                sequence.extend(current_bigram)
        
        return sequence
    
    def generate_harmonization(self, melody_notes, length=None):
        """Generate harmonization for a given melody"""
        if len(self.harmony_model) == 0:
            raise ValueError("Harmony model not trained yet!")
        
        harmonized_sequence = []
        
        # If melody_notes is a list of MIDI note numbers, convert to symbols
        if isinstance(melody_notes[0], int):
            melody_symbols = []
            for note in melody_notes:
                pitch_class = note % 12
                octave = note // 12
                # Use default velocity and timing for input melody
                symbol = f"P{pitch_class}_O{octave}_mf_T3"
                melody_symbols.append(symbol)
            melody_notes = melody_symbols
        
        # Extend melody to reach target length if specified
        if length is not None:
            if len(melody_notes) < length:
                # Repeat the melody pattern to reach desired length
                extended_melody = []
                for i in range(length):
                    extended_melody.append(melody_notes[i % len(melody_notes)])
                melody_notes = extended_melody
            else:
                # If melody is already longer than target, truncate it
                melody_notes = melody_notes[:length]
        
        for melody_symbol in melody_notes:
            # Add the original melody note
            harmonized_sequence.append(melody_symbol)
            
            # Extract pitch class from melody note
            if melody_symbol.startswith('P'):
                try:
                    parts = melody_symbol.split('_')
                    pitch_class = int(parts[0][1:])
                    octave = int(parts[1][1:])
                    
                    melody_key = f"M{pitch_class}"
                    
                    if melody_key in self.harmony_model:
                        # Choose harmony based on learned patterns
                        harmony_options = self.harmony_model[melody_key]
                        total_count = sum(harmony_options.values())
                        
                        if total_count > 0:
                            # Weighted random selection
                            weighted_choices = []
                            for harmony_pattern, count in harmony_options.items():
                                weighted_choices.extend([harmony_pattern] * count)
                            
                            chosen_harmony = random.choice(weighted_choices)
                            
                            # Convert harmony pattern back to note symbols
                            harmony_notes = chosen_harmony.split('_')
                            for harmony_note in harmony_notes:
                                if harmony_note.startswith('H'):
                                    harmony_pitch = int(harmony_note[1:])
                                    # Place harmony in appropriate octave (usually higher)
                                    harmony_octave = octave if harmony_pitch > pitch_class else octave + 1
                                    harmony_octave = min(7, harmony_octave)  # Keep in range
                                    
                                    harmony_symbol = f"P{harmony_pitch}_O{harmony_octave}_mp_T3"
                                    harmonized_sequence.append(harmony_symbol)
                
                except (ValueError, IndexError):
                    pass  # Skip if parsing fails
        
        return harmonized_sequence

    def generate_melody_from_chords(self, chord_progression, length=100):
        """Generate melody that follows a chord progression"""
        if len(self.melody_model) == 0:
            raise ValueError("Melody model not trained yet!")
        
        melody_sequence = []
        
        # Convert chord progression to our internal format if needed
        if isinstance(chord_progression[0], list):
            # chord_progression is list of lists of MIDI notes
            chord_symbols = []
            for chord_notes in chord_progression:
                pitch_classes = sorted([n % 12 for n in chord_notes])
                chord_key = "_".join([f"C{pc}" for pc in pitch_classes])
                chord_symbols.append(chord_key)
            chord_progression = chord_symbols
        
        notes_per_chord = max(1, length // len(chord_progression))
        
        for chord_symbol in chord_progression:
            # Generate melody notes for this chord
            for _ in range(notes_per_chord):
                if chord_symbol in self.melody_model:
                    melody_options = self.melody_model[chord_symbol]
                    total_count = sum(melody_options.values())
                    
                    if total_count > 0:
                        # Weighted random selection
                        weighted_choices = []
                        for melody_pattern, count in melody_options.items():
                            weighted_choices.extend([melody_pattern] * count)
                        
                        chosen_melody = random.choice(weighted_choices)
                        
                        # Convert back to full symbol
                        if chosen_melody.startswith('M'):
                            pitch_class = int(chosen_melody[1:])
                            octave = random.choice([4, 5, 6])  # Melody range
                            velocity = random.choice(['mp', 'mf', 'f'])
                            timing = random.choice(['T2', 'T3', 'T4'])
                            
                            melody_symbol = f"P{pitch_class}_O{octave}_{velocity}_{timing}"
                            melody_sequence.append(melody_symbol)
                else:
                    # Fallback: generate from unconditional model
                    if len(self.trigram_model) > 0:
                        current_bigram = random.choice(list(self.trigram_model.keys()))
                        melody_sequence.extend(current_bigram)
        
        return melody_sequence[:length]
    
    def generate_style_transfer(self, input_melody, target_style_velocity="f", target_style_timing="T2"):
        """Transfer the style of an input melody (change velocity/timing patterns)"""
        styled_sequence = []
        
        # If input is MIDI notes, convert first
        if isinstance(input_melody[0], int):
            input_symbols = []
            for note in input_melody:
                pitch_class = note % 12
                octave = note // 12
                symbol = f"P{pitch_class}_O{octave}_mf_T3"
                input_symbols.append(symbol)
            input_melody = input_symbols
        
        for symbol in input_melody:
            if symbol.startswith('P'):
                try:
                    parts = symbol.split('_')
                    pitch_part = parts[0]  # P{pitch_class}
                    octave_part = parts[1]  # O{octave}
                    
                    # Apply style transfer
                    new_symbol = f"{pitch_part}_{octave_part}_{target_style_velocity}_{target_style_timing}"
                    styled_sequence.append(new_symbol)
                    
                except (ValueError, IndexError):
                    styled_sequence.append(symbol)  # Keep original if parsing fails
            else:
                styled_sequence.append(symbol)
        
        return styled_sequence
    
    def sequence_to_midi(self, sequence, output_path="generated_music.mid"):
        """Convert generated sequence back to MIDI file with proper timing"""
        mid = MidiFile(ticks_per_beat=480)
        track = MidiTrack()
        mid.tracks.append(track)
        
        # Set default tempo
        default_tempo = 500000 if not self.tempos else random.choice(self.tempos)
        track.append(mido.MetaMessage('set_tempo', tempo=int(default_tempo), time=0))
        
        # Add time signature
        track.append(mido.MetaMessage('time_signature', numerator=4, denominator=4, time=0))
        
        # Store events with absolute timing first
        events = []
        current_time = 0
        
        for i, symbol in enumerate(sequence):
            if symbol.startswith('P'):
                try:
                    parts = symbol.split('_')
                    if len(parts) >= 4:
                        pitch_class = int(parts[0][1:])
                        octave = int(parts[1][1:])
                        vel_level = parts[2]
                        timing = parts[3]
                        
                        # Constrain octave to reasonable range
                        octave = max(3, min(7, octave))
                        note = (octave * 12) + pitch_class
                        
                        # Ensure note is in valid MIDI range (0-127)
                        note = max(0, min(127, note))
                        
                        # Convert velocity level to MIDI velocity
                        velocity_map = {
                            "pp": 35, "mp": 55, "mf": 75, "f": 95, "ff": 115
                        }
                        velocity = velocity_map.get(vel_level, 70)
                        
                        # Convert timing to ticks - make them shorter for better playback
                        timing_map = {
                            "T1": 240,   # Eighth note
                            "T2": 480,   # Quarter note  
                            "T3": 720,   # Dotted quarter
                            "T4": 960,   # Half note
                            "T5": 1440   # Dotted half
                        }
                        duration = timing_map.get(timing, 480)
                        
                        # Add note on event
                        events.append(('note_on', current_time, note, velocity))
                        # Add note off event
                        events.append(('note_off', current_time + int(duration * 0.9), note, 0))
                        
                        # Advance time for next note (with some overlap allowed)
                        current_time += int(duration * 0.7)  # 70% spacing allows overlap
                        
                except (ValueError, IndexError):
                    current_time += 480  # Default quarter note spacing
            else:
                current_time += 240  # Shorter default for non-notes
        
        # Sort events by time
        events.sort(key=lambda x: x[1])
        
        # Convert to MIDI messages with delta times
        last_time = 0
        for event in events:
            event_type, abs_time, note, velocity = event
            delta_time = abs_time - last_time
            
            if event_type == 'note_on':
                track.append(mido.Message('note_on', channel=0, note=note, 
                                        velocity=velocity, time=delta_time))
            else:  # note_off
                track.append(mido.Message('note_off', channel=0, note=note, 
                                        velocity=64, time=delta_time))
            
            last_time = abs_time
        
        # Add a final rest
        track.append(mido.Message('note_off', channel=0, note=60, velocity=0, time=480))
        
        mid.save(output_path)
        print(f"Generated MIDI saved as: {output_path}")
        print(f"Total events: {len(events)}")
        print(f"Duration: ~{current_time / 480:.1f} beats")
    
    def save_model(self, filepath):
        """Save the trained model"""
        model_data = {
            'trigram_model': dict(self.trigram_model),
            'harmony_model': dict(self.harmony_model),
            'melody_model': dict(self.melody_model),
            'chord_progressions': dict(self.chord_progressions),
            'tempos': self.tempos,
            'time_signatures': self.time_signatures
        }
        with open(filepath, 'wb') as f:
            pickle.dump(model_data, f)
        print(f"Model saved to: {filepath}")
    
    def load_model(self, filepath):
        """Load a trained model"""
        with open(filepath, 'rb') as f:
            model_data = pickle.load(f)
        
        self.trigram_model = defaultdict(Counter, model_data['trigram_model'])
        self.harmony_model = defaultdict(Counter, model_data.get('harmony_model', {}))
        self.melody_model = defaultdict(Counter, model_data.get('melody_model', {}))
        self.chord_progressions = defaultdict(Counter, model_data.get('chord_progressions', {}))
        self.tempos = model_data['tempos']
        self.time_signatures = model_data['time_signatures']
        print(f"Model loaded from: {filepath}")

# Example usage for conditional generation
def example_conditional_generation():
    """Example of how to use the conditional generation features"""
    
    # Initialize and train the generator
    generator = SymbolicMusicGenerator()
    
    # Train on dataset (this builds all models: trigram, harmony, melody)
    generator.train_on_dataset("maestro-v3.0.0", max_files=300)
    generator.save_model("conditional_music_model.pkl")
    
    print("\n=== CONDITIONAL GENERATION EXAMPLES ===")
    
    # 1. HARMONIZATION: Generate harmony for a melody
    print("\n1. Harmonization Example:")
    # Input melody: C-E-G-F (MIDI notes)
    input_melody = [60, 64, 67, 65]  # C4, E4, G4, F4
    harmonized = generator.generate_harmonization(input_melody, 500)
    generator.sequence_to_midi(harmonized, "harmonized_melody.mid")
    print(f"Original melody had {len(input_melody)} notes")
    print(f"Harmonized version has {len(harmonized)} notes (melody + harmony)")
    
    # 2. MELODY FROM CHORDS: Generate melody that follows chord progression
    print("\n2. Melody from Chords Example:")
    # Input: C major - F major - G major - C major chord progression
    chord_progression = [
        [60, 64, 67],  # C major (C-E-G)
        [65, 69, 72],  # F major (F-A-C)
        [67, 71, 74],  # G major (G-B-D)  
        [60, 64, 67]   # C major (C-E-G)
    ]
    melody_from_chords = generator.generate_melody_from_chords(chord_progression, length=500)
    generator.sequence_to_midi(melody_from_chords, "melody_from_chords.mid")
    print(f"Generated {len(melody_from_chords)} melody notes from {len(chord_progression)} chords")
    
    # 3. STYLE TRANSFER: Change the style of existing melody
    print("\n3. Style Transfer Example:")
    original_melody = [60, 62, 64, 65, 67, 69, 71, 72]  # C major scale
    
    # Create different styles
    energetic_style = generator.generate_style_transfer(original_melody, 
                                                      target_style_velocity="ff", 
                                                      target_style_timing="T1")
    gentle_style = generator.generate_style_transfer(original_melody,
                                                   target_style_velocity="pp",
                                                   target_style_timing="T4")
    
    generator.sequence_to_midi(energetic_style, "energetic_style.mid")
    generator.sequence_to_midi(gentle_style, "gentle_style.mid")
    print("Created energetic and gentle versions of the same melody")
    
    # 4. UNCONDITIONAL GENERATION (original functionality)
    print("\n4. Unconditional Generation (for comparison):")
    unconditional = generator.generate_sequence(length=100)
    generator.sequence_to_midi(unconditional, "unconditional_generation.mid")
    print(f"Generated {len(unconditional)} notes unconditionally")
    
    print("\n=== Generated Files ===")
    print("- harmonized_melody.mid: Melody with added harmony")
    print("- melody_from_chords.mid: Melody following chord progression") 
    print("- energetic_style.mid: Fast, loud version of scale")
    print("- gentle_style.mid: Slow, soft version of scale")
    print("- unconditional_generation.mid: Original random generation")

# %%
# Train and generate
generator = SymbolicMusicGenerator()
generator.train_on_dataset("maestro-v3.0.0", max_files=500)

chord_progression = [
        [60, 64, 67],  # C major (C-E-G)
        [65, 69, 72],  # F major (F-A-C)
        [67, 71, 74],  # G major (G-B-D)  
        [60, 64, 67]   # C major (C-E-G)
    ]

chord_melody = generator.generate_melody_from_chords(chord_progression, length=500)
energetic_chord = generator.generate_style_transfer(chord_melody, target_style_velocity="ff", target_style_timing="T1")
generator.sequence_to_midi(energetic_chord, "task2.mid")
# Out:
# Scanning for MIDI files...
# Found 1276 MIDI files
# Processing 500 randomly selected files
# Processing: MIDI-Unprocessed_22_R2_2006_01_ORIG_MID--AUDIO_22_R2_2006_02_Track02_wav.midi (1/500)
# Processing: MIDI-UNPROCESSED_01-03_R1_2014_MID--AUDIO_02_R1_2014_wav--5.midi (2/500)
# Processing: MIDI-UNPROCESSED_19-21_R3_2014_MID--AUDIO_21_R3_2014_wav--2.midi (3/500)
# Processing: ORIG-MIDI_03_7_10_13_Group_MID--AUDIO_15_R3_2013_wav--1.midi (4/500)
# Processing: MIDI-Unprocessed_06_R1_2006_01-04_ORIG_MID--AUDIO_06_R1_2006_03_Track03_wav.midi (5/500)
# Processing: MIDI-Unprocessed_23_R2_2006_01_ORIG_MID--AUDIO_23_R2_2006_03_Track03_wav.midi (6/500)
# Processing: MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_01_R1_2015_wav--3.midi (7/500)
# Processing: MIDI-Unprocessed_25_R1_2011_MID--AUDIO_R1-D9_15_Track15_wav.midi (8/500)
# Processing: MIDI-Unprocessed_06_R1_2008_01-04_ORIG_MID--AUDIO_06_R1_2008_wav--1.midi (9/500)
# Processing: MIDI-Unprocessed_03_R1_2009_03-08_ORIG_MID--AUDIO_03_R1_2009_03_R1_2009_04_WAV.midi (10/500)
# Processing: MIDI-UNPROCESSED_16-18_R1_2014_MID--AUDIO_16_R1_2014_wav--3.midi (11/500)
# Processing: MIDI-Unprocessed_065_PIANO065_MID--AUDIO-split_07-07-17_Piano-e_3-01_wav--2.midi (12/500)
# Processing: MIDI-Unprocessed_24_R1_2011_MID--AUDIO_R1-D9_08_Track08_wav.midi (13/500)
# Processing: MIDI-Unprocessed_12_R1_2011_MID--AUDIO_R1-D4_13_Track13_wav.midi (14/500)
# Processing: MIDI-Unprocessed_01_R1_2008_01-04_ORIG_MID--AUDIO_01_R1_2008_wav--1.midi (15/500)
# Processing: MIDI-Unprocessed_044_PIANO044_MID--AUDIO-split_07-06-17_Piano-e_1-04_wav--1.midi (16/500)
# Processing: MIDI-Unprocessed_17_R2_2008_01-04_ORIG_MID--AUDIO_17_R2_2008_wav--1.midi (17/500)
# Processing: MIDI-UNPROCESSED_21-22_R1_2014_MID--AUDIO_21_R1_2014_wav--7.midi (18/500)
# Processing: MIDI-Unprocessed_08_R3_2008_01-05_ORIG_MID--AUDIO_08_R3_2008_wav--1.midi (19/500)
# Processing: MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_03_R1_2015_wav--4.midi (20/500)
# Processing: MIDI-Unprocessed_11_R2_2008_01-05_ORIG_MID--AUDIO_11_R2_2008_wav--5.midi (21/500)
# Processing: MIDI-Unprocessed_R1_D2-21-22_mid--AUDIO-from_mp3_22_R1_2015_wav--1.midi (22/500)
# Processing: MIDI-Unprocessed_06_R3_2011_MID--AUDIO_R3-D3_06_Track06_wav.midi (23/500)
# Processing: MIDI-Unprocessed_Recital5-7_MID--AUDIO_07_R1_2018_wav--4.midi (24/500)
# Processing: MIDI-Unprocessed_081_PIANO081_MID--AUDIO-split_07-09-17_Piano-e_2_-02_wav--1.midi (25/500)
# Processing: MIDI-Unprocessed_14_R1_2008_01-05_ORIG_MID--AUDIO_14_R1_2008_wav--2.midi (26/500)
# Processing: MIDI-UNPROCESSED_04-05_R1_2014_MID--AUDIO_05_R1_2014_wav--6.midi (27/500)
# Processing: MIDI-Unprocessed_10_R2_2009_01_ORIG_MID--AUDIO_10_R2_2009_10_R2_2009_02_WAV.midi (28/500)
# Processing: MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_17_R1_2015_wav--1.midi (29/500)
# Processing: MIDI-Unprocessed_18_R1_2006_01-05_ORIG_MID--AUDIO_18_R1_2006_01_Track01_wav.midi (30/500)
# Processing: MIDI-Unprocessed_15_R2_2008_01-04_ORIG_MID--AUDIO_15_R2_2008_wav--4.midi (31/500)
# Processing: ORIG-MIDI_02_7_8_13_Group__MID--AUDIO_08_R2_2013_wav--2.midi (32/500)
# Processing: ORIG-MIDI_02_7_8_13_Group__MID--AUDIO_14_R2_2013_wav--1.midi (33/500)
# Processing: MIDI-Unprocessed_01_R1_2006_01-09_ORIG_MID--AUDIO_01_R1_2006_04_Track04_wav.midi (34/500)
# Processing: MIDI-Unprocessed_02_R1_2006_01-04_ORIG_MID--AUDIO_02_R1_2006_02_Track02_wav.midi (35/500)
# Processing: MIDI-Unprocessed_XP_19_R2_2004_01_ORIG_MID--AUDIO_19_R2_2004_02_Track02_wav.midi (36/500)
# Processing: MIDI-Unprocessed_12_R1_2008_01-04_ORIG_MID--AUDIO_12_R1_2008_wav--2.midi (37/500)
# Processing: MIDI-Unprocessed_09_R1_2008_01-05_ORIG_MID--AUDIO_09_R1_2008_wav--5.midi (38/500)
# Processing: MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_08_Track08_wav.midi (39/500)
# Processing: MIDI-Unprocessed_11_R1_2008_01-04_ORIG_MID--AUDIO_11_R1_2008_wav--1.midi (40/500)
# Processing: MIDI-UNPROCESSED_09-10_R1_2014_MID--AUDIO_10_R1_2014_wav--3.midi (41/500)
# Processing: MIDI-Unprocessed_SMF_17_R1_2004_01-03_ORIG_MID--AUDIO_17_R1_2004_02_Track02_wav--2.midi (42/500)
# Processing: MIDI-Unprocessed_044_PIANO044_MID--AUDIO-split_07-06-17_Piano-e_1-04_wav--4.midi (43/500)
# Processing: MIDI-Unprocessed_R1_D2-21-22_mid--AUDIO-from_mp3_21_R1_2015_wav--5.midi (44/500)
# Processing: MIDI-Unprocessed_Recital5-7_MID--AUDIO_07_R1_2018_wav--3.midi (45/500)
# Processing: MIDI-UNPROCESSED_09-10_R1_2014_MID--AUDIO_10_R1_2014_wav--1.midi (46/500)
# Processing: MIDI-Unprocessed_R2_D1-2-3-6-7-8-11_mid--AUDIO-from_mp3_08_R2_2015_wav--2.midi (47/500)
# Processing: MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_02_R1_2015_wav--3.midi (48/500)
# Processing: MIDI-Unprocessed_Recital1-3_MID--AUDIO_03_R1_2018_wav--2.midi (49/500)
# Processing: MIDI-UNPROCESSED_21-22_R1_2014_MID--AUDIO_22_R1_2014_wav--4.midi (50/500)
# Processing: MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_10_Track10_wav.midi (51/500)
# Processing: MIDI-Unprocessed_11_R1_2009_01-05_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_02_WAV.midi (52/500)
# Processing: MIDI-Unprocessed_01_R1_2008_01-04_ORIG_MID--AUDIO_01_R1_2008_wav--2.midi (53/500)
# Processing: MIDI-Unprocessed_SMF_13_01_2004_01-05_ORIG_MID--AUDIO_13_R1_2004_02_Track02_wav.midi (54/500)
# Processing: MIDI-Unprocessed_Schubert4-6_MID--AUDIO_09_R2_2018_wav.midi (55/500)
# Processing: MIDI-Unprocessed_22_R3_2011_MID--AUDIO_R3-D7_09_Track09_wav.midi (56/500)
# Processing: MIDI-Unprocessed_08_R2_2008_01-04_ORIG_MID--AUDIO_08_R2_2008_wav--1.midi (57/500)
# Processing: MIDI-Unprocessed_074_PIANO074_MID--AUDIO-split_07-08-17_Piano-e_2-04_wav--3.midi (58/500)
# Processing: MIDI-Unprocessed_03_R1_2008_01-04_ORIG_MID--AUDIO_03_R1_2008_wav--4.midi (59/500)
# Processing: ORIG-MIDI_01_7_6_13_Group__MID--AUDIO_03_R1_2013_wav--1.midi (60/500)
# Processing: MIDI-Unprocessed_XP_19_R1_2004_01-02_ORIG_MID--AUDIO_19_R1_2004_02_Track02_wav.midi (61/500)
# Processing: MIDI-Unprocessed_080_PIANO080_MID--AUDIO-split_07-09-17_Piano-e_1-06_wav--2.midi (62/500)
# Processing: ORIG-MIDI_01_7_8_13_Group__MID--AUDIO_03_R2_2013_wav--1.midi (63/500)
# Processing: MIDI-Unprocessed_02_R1_2009_03-06_ORIG_MID--AUDIO_02_R1_2009_02_R1_2009_03_WAV.midi (64/500)
# Processing: ORIG-MIDI_02_7_10_13_Group_MID--AUDIO_12_R3_2013_wav--1.midi (65/500)
# Processing: MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_02_R1_2015_wav--4.midi (66/500)
# Processing: MIDI-Unprocessed_Recital5-7_MID--AUDIO_05_R1_2018_wav--3.midi (67/500)
# Processing: MIDI-Unprocessed_059_PIANO059_MID--AUDIO-split_07-07-17_Piano-e_2-03_wav--3.midi (68/500)
# Processing: MIDI-Unprocessed_11_R1_2006_01-06_ORIG_MID--AUDIO_11_R1_2006_04_Track04_wav.midi (69/500)
# Processing: MIDI-UNPROCESSED_04-05_R1_2014_MID--AUDIO_05_R1_2014_wav--7.midi (70/500)
# Processing: MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_19_R1_2015_wav--2.midi (71/500)
# Processing: MIDI-Unprocessed_071_PIANO071_MID--AUDIO-split_07-08-17_Piano-e_1-04_wav--4.midi (72/500)
# Processing: MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-from_mp3_12_R1_2015_wav--2.midi (73/500)
# Processing: MIDI-Unprocessed_07_R2_2009_01_ORIG_MID--AUDIO_07_R2_2009_07_R2_2009_03_WAV.midi (74/500)
# Processing: MIDI-Unprocessed_SMF_17_R1_2004_03-06_ORIG_MID--AUDIO_20_R2_2004_12_Track12_wav--1.midi (75/500)
# Processing: MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R3_2018_wav--1.midi (76/500)
# Processing: MIDI-Unprocessed_049_PIANO049_MID--AUDIO-split_07-06-17_Piano-e_2-06_wav--1.midi (77/500)
# Processing: MIDI-UNPROCESSED_11-13_R1_2014_MID--AUDIO_13_R1_2014_wav--3.midi (78/500)
# Processing: MIDI-Unprocessed_075_PIANO075_MID--AUDIO-split_07-08-17_Piano-e_2-06_wav--3.midi (79/500)
# Processing: MIDI-Unprocessed_14_R1_2008_01-05_ORIG_MID--AUDIO_14_R1_2008_wav--1.midi (80/500)
# Processing: MIDI-UNPROCESSED_21-22_R1_2014_MID--AUDIO_21_R1_2014_wav--4.midi (81/500)
# Processing: MIDI-UNPROCESSED_01-03_R1_2014_MID--AUDIO_02_R1_2014_wav--4.midi (82/500)
# Processing: MIDI-Unprocessed_21_R2_2009_01_ORIG_MID--AUDIO_21_R2_2009_21_R2_2009_04_WAV.midi (83/500)
# Processing: MIDI-Unprocessed_12_R1_2006_01-08_ORIG_MID--AUDIO_12_R1_2006_01_Track01_wav.midi (84/500)
# Processing: MIDI-UNPROCESSED_06-08_R1_2014_MID--AUDIO_08_R1_2014_wav--2.midi (85/500)
# Processing: MIDI-Unprocessed_XP_10_R1_2004_01-02_ORIG_MID--AUDIO_10_R1_2004_01_Track01_wav.midi (86/500)
# Processing: MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_15_R1_2015_wav--3.midi (87/500)
# Processing: MIDI-Unprocessed_078_PIANO078_MID--AUDIO-split_07-09-17_Piano-e_1-02_wav--3.midi (88/500)
# Processing: MIDI-Unprocessed_25_R3_2011_MID--AUDIO_R3-D9_04_Track04_wav.midi (89/500)
# Processing: MIDI-Unprocessed_Recital8_MID--AUDIO_08_R1_2018_wav--3.midi (90/500)
# Processing: MIDI-Unprocessed_054_PIANO054_MID--AUDIO-split_07-07-17_Piano-e_1-02_wav--1.midi (91/500)
# Processing: ORIG-MIDI_01_7_8_13_Group__MID--AUDIO_02_R2_2013_wav--3.midi (92/500)
# Processing: MIDI-Unprocessed_060_PIANO060_MID--AUDIO-split_07-07-17_Piano-e_2-04_wav--1.midi (93/500)
# Processing: MIDI-Unprocessed_09_R3_2008_01-07_ORIG_MID--AUDIO_09_R3_2008_wav--4.midi (94/500)
# Processing: ORIG-MIDI_02_7_6_13_Group__MID--AUDIO_07_R1_2013_wav--3.midi (95/500)
# Processing: MIDI-Unprocessed_22_R3_2011_MID--AUDIO_R3-D7_03_Track03_wav.midi (96/500)
# Processing: MIDI-Unprocessed_14_R1_2009_01-05_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_03_WAV.midi (97/500)
# Processing: MIDI-Unprocessed_052_PIANO052_MID--AUDIO-split_07-06-17_Piano-e_3-03_wav--3.midi (98/500)
# Processing: ORIG-MIDI_02_7_7_13_Group__MID--AUDIO_18_R1_2013_wav--4.midi (99/500)
# Processing: MIDI-UNPROCESSED_11-13_R1_2014_MID--AUDIO_12_R1_2014_wav--1.midi (100/500)
# Processing: MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_08_R1_2015_wav--1.midi (101/500)
# Processing: MIDI-Unprocessed_067_PIANO067_MID--AUDIO-split_07-07-17_Piano-e_3-03_wav--2.midi (102/500)
# Processing: MIDI-Unprocessed_04_R1_2011_MID--AUDIO_R1-D2_04_Track04_wav.midi (103/500)
# Processing: MIDI-Unprocessed_048_PIANO048_MID--AUDIO-split_07-06-17_Piano-e_2-05_wav--2.midi (104/500)
# Processing: MIDI-Unprocessed_R1_D2-21-22_mid--AUDIO-from_mp3_22_R1_2015_wav--3.midi (105/500)
# Processing: MIDI-Unprocessed_XP_01_R1_2004_04-05_ORIG_MID--AUDIO_01_R1_2004_05_Track05_wav.midi (106/500)
# Processing: MIDI-Unprocessed_19_R1_2009_03-04_ORIG_MID--AUDIO_19_R1_2009_19_R1_2009_04_WAV.midi (107/500)
# Processing: MIDI-Unprocessed_16_R1_2006_01-04_ORIG_MID--AUDIO_16_R1_2006_02_Track02_wav.midi (108/500)
# Processing: MIDI-Unprocessed_062_PIANO062_MID--AUDIO-split_07-07-17_Piano-e_2-07_wav--3.midi (109/500)
# Processing: MIDI-Unprocessed_07_R2_2006_01_ORIG_MID--AUDIO_07_R2_2006_02_Track02_wav.midi (110/500)
# Processing: MIDI-Unprocessed_SMF_17_R1_2004_04_ORIG_MID--AUDIO_17_R1_2004_09_Track09_wav.midi (111/500)
# Processing: MIDI-UNPROCESSED_09-10_R1_2014_MID--AUDIO_09_R1_2014_wav--1.midi (112/500)
# Processing: MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_07_R1_2015_wav--2.midi (113/500)
# Processing: ORIG-MIDI_01_7_7_13_Group__MID--AUDIO_14_R1_2013_wav--4.midi (114/500)
# Processing: MIDI-Unprocessed_17_R2_2008_01-04_ORIG_MID--AUDIO_17_R2_2008_wav--3.midi (115/500)
# Processing: MIDI-Unprocessed_XP_22_R2_2004_01_ORIG_MID--AUDIO_22_R2_2004_01_Track01_wav.midi (116/500)
# Processing: MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_02_R1_2015_wav--5.midi (117/500)
# Processing: MIDI-Unprocessed_07_R1_2009_04-05_ORIG_MID--AUDIO_07_R1_2009_07_R1_2009_05_WAV.midi (118/500)
# Processing: MIDI-Unprocessed_R2_D2-19-21-22_mid--AUDIO-from_mp3_22_R2_2015_wav--3.midi (119/500)
# Processing: MIDI-Unprocessed_082_PIANO082_MID--AUDIO-split_07-09-17_Piano-e_2_-04_wav--1.midi (120/500)
# Processing: ORIG-MIDI_01_7_6_13_Group__MID--AUDIO_02_R1_2013_wav--1.midi (121/500)
# Processing: MIDI-Unprocessed_R2_D2-19-21-22_mid--AUDIO-from_mp3_21_R2_2015_wav--1.midi (122/500)
# Processing: MIDI-Unprocessed_055_PIANO055_MID--AUDIO-split_07-07-17_Piano-e_1-04_wav--2.midi (123/500)
# Processing: MIDI-Unprocessed_02_R1_2009_03-06_ORIG_MID--AUDIO_02_R1_2009_02_R1_2009_05_WAV.midi (124/500)
# Processing: MIDI-UNPROCESSED_19-21_R3_2014_MID--AUDIO_21_R3_2014_wav--1.midi (125/500)
# Processing: MIDI-Unprocessed_SMF_16_R1_2004_01-08_ORIG_MID--AUDIO_16_R1_2004_05_Track05_wav.midi (126/500)
# Processing: MIDI-Unprocessed_XP_18_R1_2004_04_ORIG_MID--AUDIO_18_R1_2004_07_Track07_wav.midi (127/500)
# Processing: MIDI-Unprocessed_10_R1_2008_01-04_ORIG_MID--AUDIO_10_R1_2008_wav--2.midi (128/500)
# Processing: MIDI-Unprocessed_04_R1_2006_01-04_ORIG_MID--AUDIO_04_R1_2006_03_Track03_wav.midi (129/500)
# Processing: MIDI-Unprocessed_19_R2_2009_01_ORIG_MID--AUDIO_19_R2_2009_19_R2_2009_04_WAV.midi (130/500)
# Processing: MIDI-Unprocessed_SMF_12_01_2004_01-05_ORIG_MID--AUDIO_12_R1_2004_07_Track07_wav.midi (131/500)
# Processing: MIDI-Unprocessed_24_R1_2011_MID--AUDIO_R1-D9_11_Track11_wav.midi (132/500)
# Processing: MIDI-UNPROCESSED_11-13_R1_2014_MID--AUDIO_13_R1_2014_wav--6.midi (133/500)
# Processing: MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_03_R1_2015_wav--2.midi (134/500)
# Processing: MIDI-UNPROCESSED_09-10_R1_2014_MID--AUDIO_10_R1_2014_wav--5.midi (135/500)
# Processing: MIDI-Unprocessed_05_R1_2006_01-05_ORIG_MID--AUDIO_05_R1_2006_02_Track02_wav.midi (136/500)
# Processing: MIDI-Unprocessed_052_PIANO052_MID--AUDIO-split_07-06-17_Piano-e_3-03_wav--1.midi (137/500)
# Processing: MIDI-Unprocessed_03_R1_2006_01-05_ORIG_MID--AUDIO_03_R1_2006_05_Track05_wav.midi (138/500)
# Processing: MIDI-Unprocessed_21_R2_2009_01_ORIG_MID--AUDIO_21_R2_2009_21_R2_2009_01_WAV.midi (139/500)
# Processing: MIDI-Unprocessed_12_R1_2009_03-05_ORIG_MID--AUDIO_12_R1_2009_12_R1_2009_03_WAV.midi (140/500)
# Processing: MIDI-Unprocessed_09_R1_2008_01-05_ORIG_MID--AUDIO_09_R1_2008_wav--3.midi (141/500)
# Processing: MIDI-Unprocessed_18_R1_2009_04_ORIG_MID--AUDIO_18_R1_2009_18_R1_2009_04_WAV.midi (142/500)
# Processing: MIDI-Unprocessed_080_PIANO080_MID--AUDIO-split_07-09-17_Piano-e_1-06_wav--1.midi (143/500)
# Processing: MIDI-Unprocessed_056_PIANO056_MID--AUDIO-split_07-07-17_Piano-e_1-05_wav--3.midi (144/500)
# Processing: MIDI-Unprocessed_18_R1_2006_01-05_ORIG_MID--AUDIO_18_R1_2006_02_Track02_wav.midi (145/500)
# Processing: MIDI-Unprocessed_23_R1_2011_MID--AUDIO_R1-D9_05_Track05_wav.midi (146/500)
# Processing: ORIG-MIDI_03_7_8_13_Group__MID--AUDIO_17_R2_2013_wav--2.midi (147/500)
# Processing: MIDI-Unprocessed_21_R1_2006_01-04_ORIG_MID--AUDIO_21_R1_2006_02_Track02_wav.midi (148/500)
# Processing: MIDI-Unprocessed_11_R3_2008_01-04_ORIG_MID--AUDIO_11_R3_2008_wav--2.midi (149/500)
# Processing: MIDI-Unprocessed_XP_09_R1_2004_05_ORIG_MID--AUDIO_09_R1_2004_07_Track07_wav.midi (150/500)
# Processing: MIDI-Unprocessed_078_PIANO078_MID--AUDIO-split_07-09-17_Piano-e_1-02_wav--2.midi (151/500)
# Processing: MIDI-Unprocessed_R2_D1-2-3-6-7-8-11_mid--AUDIO-from_mp3_07_R2_2015_wav--2.midi (152/500)
# Processing: ORIG-MIDI_01_7_6_13_Group__MID--AUDIO_01_R1_2013_wav--4.midi (153/500)
# Processing: MIDI-Unprocessed_01_R1_2006_01-09_ORIG_MID--AUDIO_01_R1_2006_03_Track03_wav.midi (154/500)
# Processing: MIDI-Unprocessed_16_R1_2011_MID--AUDIO_R1-D6_14_Track14_wav.midi (155/500)
# Processing: MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-from_mp3_11_R1_2015_wav--5.midi (156/500)
# Processing: MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_15_R2_2015_wav--3.midi (157/500)
# Processing: MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-from_mp3_09_R1_2015_wav--1.midi (158/500)
# Processing: MIDI-Unprocessed_12_R1_2009_03-05_ORIG_MID--AUDIO_12_R1_2009_12_R1_2009_05_WAV.midi (159/500)
# Processing: MIDI-Unprocessed_05_R1_2011_MID--AUDIO_R1-D2_10_Track10_wav.midi (160/500)
# Processing: ORIG-MIDI_03_7_6_13_Group__MID--AUDIO_09_R1_2013_wav--1.midi (161/500)
# Processing: MIDI-Unprocessed_03_R2_2008_01-03_ORIG_MID--AUDIO_03_R2_2008_wav--3.midi (162/500)
# Processing: MIDI-UNPROCESSED_06-08_R1_2014_MID--AUDIO_07_R1_2014_wav--6.midi (163/500)
# Processing: MIDI-Unprocessed_21_R1_2009_04_ORIG_MID--AUDIO_21_R1_2009_21_R1_2009_04_WAV.midi (164/500)
# Processing: MIDI-Unprocessed_22_R1_2011_MID--AUDIO_R1-D8_11_Track11_wav.midi (165/500)
# Processing: MIDI-Unprocessed_SMF_07_R1_2004_01_ORIG_MID--AUDIO_07_R1_2004_12_Track12_wav.midi (166/500)
# Processing: MIDI-Unprocessed_14_R1_2008_01-05_ORIG_MID--AUDIO_14_R1_2008_wav--3.midi (167/500)
# Processing: MIDI-UNPROCESSED_09-10_R1_2014_MID--AUDIO_09_R1_2014_wav--2.midi (168/500)
# Processing: MIDI-Unprocessed_042_PIANO042_MID--AUDIO-split_07-06-17_Piano-e_1-02_wav--2.midi (169/500)
# Processing: MIDI-Unprocessed_10_R2_2008_01-05_ORIG_MID--AUDIO_10_R2_2008_wav--1.midi (170/500)
# Processing: MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_07_R1_2015_wav--4.midi (171/500)
# Processing: MIDI-Unprocessed_17_R1_2008_01-04_ORIG_MID--AUDIO_17_R1_2008_wav--3.midi (172/500)
# Processing: MIDI-Unprocessed_17_R2_2008_01-04_ORIG_MID--AUDIO_17_R2_2008_wav--2.midi (173/500)
# Processing: MIDI-Unprocessed_22_R2_2011_MID--AUDIO_R2-D5_08_Track08_wav.midi (174/500)
# Processing: MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-from_mp3_12_R1_2015_wav--4.midi (175/500)
# Processing: MIDI-Unprocessed_02_R1_2009_01-02_ORIG_MID--AUDIO_02_R1_2009_02_R1_2009_01_WAV.midi (176/500)
# Processing: MIDI-Unprocessed_XP_15_R1_2004_04_ORIG_MID--AUDIO_15_R1_2004_04_Track04_wav.midi (177/500)
# Processing: MIDI-Unprocessed_XP_15_R2_2004_01_ORIG_MID--AUDIO_15_R2_2004_04_Track04_wav.midi (178/500)
# Processing: MIDI-Unprocessed_XP_21_R1_2004_03_ORIG_MID--AUDIO_21_R1_2004_04_Track04_wav.midi (179/500)
# Processing: ORIG-MIDI_01_7_8_13_Group__MID--AUDIO_07_R2_2013_wav--2.midi (180/500)
# Processing: MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_08_R1_2015_wav--2.midi (181/500)
# Processing: MIDI-Unprocessed_XP_21_R1_2004_01_ORIG_MID--AUDIO_21_R1_2004_01_Track01_wav.midi (182/500)
# Processing: MIDI-Unprocessed_04_R1_2008_01-04_ORIG_MID--AUDIO_04_R1_2008_wav--1.midi (183/500)
# Processing: MIDI-Unprocessed_072_PIANO072_MID--AUDIO-split_07-08-17_Piano-e_1-06_wav--2.midi (184/500)
# Processing: MIDI-Unprocessed_09_R2_2008_01-05_ORIG_MID--AUDIO_09_R2_2008_wav--3.midi (185/500)
# Processing: MIDI-Unprocessed_083_PIANO083_MID--AUDIO-split_07-09-17_Piano-e_2_-06_wav--3.midi (186/500)
# Processing: MIDI-Unprocessed_060_PIANO060_MID--AUDIO-split_07-07-17_Piano-e_2-04_wav--4.midi (187/500)
# Processing: MIDI-Unprocessed_16_R1_2006_01-04_ORIG_MID--AUDIO_16_R1_2006_01_Track01_wav.midi (188/500)
# Processing: ORIG-MIDI_01_7_10_13_Group_MID--AUDIO_07_R3_2013_wav--3.midi (189/500)
# Processing: MIDI-Unprocessed_SMF_07_R1_2004_01_ORIG_MID--AUDIO_07_R1_2004_04_Track04_wav.midi (190/500)
# Processing: MIDI-Unprocessed_Recital1-3_MID--AUDIO_02_R1_2018_wav--4.midi (191/500)
# Processing: MIDI-Unprocessed_13_R1_2006_01-06_ORIG_MID--AUDIO_13_R1_2006_01_Track01_wav.midi (192/500)
# Processing: MIDI-Unprocessed_11_R2_2008_01-05_ORIG_MID--AUDIO_11_R2_2008_wav--2.midi (193/500)
# Processing: MIDI-UNPROCESSED_06-08_R1_2014_MID--AUDIO_07_R1_2014_wav--4.midi (194/500)
# Processing: MIDI-Unprocessed_11_R1_2006_01-06_ORIG_MID--AUDIO_11_R1_2006_02_Track02_wav.midi (195/500)
# Processing: MIDI-Unprocessed_11_R2_2008_01-05_ORIG_MID--AUDIO_11_R2_2008_wav--3.midi (196/500)
# Processing: MIDI-Unprocessed_22_R1_2006_01-04_ORIG_MID--AUDIO_22_R1_2006_01_Track01_wav.midi (197/500)
# Processing: MIDI-Unprocessed_SMF_13_01_2004_01-05_ORIG_MID--AUDIO_13_R1_2004_05_Track05_wav.midi (198/500)
# Processing: MIDI-Unprocessed_Recital1-3_MID--AUDIO_01_R1_2018_wav--3.midi (199/500)
# Processing: ORIG-MIDI_02_7_7_13_Group__MID--AUDIO_17_R1_2013_wav--1.midi (200/500)
# Processing: MIDI-Unprocessed_01_R1_2008_01-04_ORIG_MID--AUDIO_01_R1_2008_wav--3.midi (201/500)
# Processing: MIDI-Unprocessed_18_R1_2009_01-03_ORIG_MID--AUDIO_18_R1_2009_18_R1_2009_01_WAV.midi (202/500)
# Processing: MIDI-Unprocessed_R1_D2-21-22_mid--AUDIO-from_mp3_21_R1_2015_wav--4.midi (203/500)
# Processing: MIDI-Unprocessed_16_R2_2006_01_ORIG_MID--AUDIO_16_R2_2006_03_Track03_wav.midi (204/500)
# Processing: MIDI-Unprocessed_XP_15_R1_2004_03_ORIG_MID--AUDIO_15_R1_2004_03_Track03_wav.midi (205/500)
# Processing: MIDI-Unprocessed_19_R1_2006_01-07_ORIG_MID--AUDIO_19_R1_2006_01_Track01_wav.midi (206/500)
# Processing: MIDI-Unprocessed_08_R2_2009_01_ORIG_MID--AUDIO_08_R2_2009_08_R2_2009_02_WAV.midi (207/500)
# Processing: MIDI-Unprocessed_22_R1_2011_MID--AUDIO_R1-D8_12_Track12_wav.midi (208/500)
# Processing: MIDI-Unprocessed_SMF_16_R1_2004_01-08_ORIG_MID--AUDIO_16_R1_2004_13_Track13_wav.midi (209/500)
# Processing: MIDI-Unprocessed_17_R1_2006_01-06_ORIG_MID--AUDIO_17_R1_2006_01_Track01_wav.midi (210/500)
# Processing: MIDI-Unprocessed_16_R3_2011_MID--AUDIO_R3-D5_02_Track02_wav.midi (211/500)
# Processing: ORIG-MIDI_03_7_8_13_Group__MID--AUDIO_18_R2_2013_wav--4.midi (212/500)
# Processing: MIDI-Unprocessed_20_R1_2006_01-04_ORIG_MID--AUDIO_20_R1_2006_01_Track01_wav.midi (213/500)
# Processing: ORIG-MIDI_01_7_8_13_Group__MID--AUDIO_03_R2_2013_wav--2.midi (214/500)
# Processing: ORIG-MIDI_02_7_7_13_Group__MID--AUDIO_16_R1_2013_wav--1.midi (215/500)
# Processing: MIDI-Unprocessed_Recital8_MID--AUDIO_08_R1_2018_wav--1.midi (216/500)
# Processing: MIDI-Unprocessed_14_R1_2009_01-05_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_02_WAV.midi (217/500)
# Processing: MIDI-Unprocessed_R2_D1-2-3-6-7-8-11_mid--AUDIO-from_mp3_11_R2_2015_wav--2.midi (218/500)
# Processing: MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_06_R1_2015_wav--2.midi (219/500)
# Processing: ORIG-MIDI_02_7_7_13_Group__MID--AUDIO_15_R1_2013_wav--4.midi (220/500)
# Processing: MIDI-Unprocessed_09_R1_2011_MID--AUDIO_R1-D3_12_Track12_wav.midi (221/500)
# Processing: MIDI-Unprocessed_Schubert7-9_MID--AUDIO_16_R2_2018_wav.midi (222/500)
# Processing: MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_17_R1_2015_wav--2.midi (223/500)
# Processing: MIDI-Unprocessed_06_R1_2011_MID--AUDIO_R1-D2_14_Track14_wav.midi (224/500)
# Processing: ORIG-MIDI_01_7_8_13_Group__MID--AUDIO_04_R2_2013_wav--3.midi (225/500)
# Processing: MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_14_R1_2015_wav--1.midi (226/500)
# Processing: MIDI-Unprocessed_19_R2_2009_01_ORIG_MID--AUDIO_19_R2_2009_19_R2_2009_01_WAV.midi (227/500)
# Processing: MIDI-Unprocessed_08_R3_2008_01-05_ORIG_MID--AUDIO_08_R3_2008_wav--2.midi (228/500)
# Processing: MIDI-Unprocessed_SMF_13_01_2004_01-05_ORIG_MID--AUDIO_13_R1_2004_09_Track09_wav.midi (229/500)
# Processing: MIDI-Unprocessed_R1_D2-21-22_mid--AUDIO-from_mp3_22_R1_2015_wav--4.midi (230/500)
# Processing: MIDI-Unprocessed_17_R2_2009_01_ORIG_MID--AUDIO_17_R2_2009_17_R2_2009_03_WAV.midi (231/500)
# Processing: MIDI-Unprocessed_06_R1_2009_03-07_ORIG_MID--AUDIO_06_R1_2009_06_R1_2009_07_WAV.midi (232/500)
# Processing: MIDI-Unprocessed_12_R2_2011_MID--AUDIO_R2-D4_03_Track03_wav.midi (233/500)
# Processing: MIDI-Unprocessed_R1_D2-21-22_mid--AUDIO-from_mp3_22_R1_2015_wav--2.midi (234/500)
# Processing: MIDI-Unprocessed_Recital5-7_MID--AUDIO_06_R1_2018_wav--1.midi (235/500)
# Processing: ORIG-MIDI_02_7_8_13_Group__MID--AUDIO_14_R2_2013_wav--4.midi (236/500)
# Processing: ORIG-MIDI_02_7_7_13_Group__MID--AUDIO_19_R1_2013_wav--1.midi (237/500)
# Processing: MIDI-Unprocessed_XP_18_R1_2004_01-02_ORIG_MID--AUDIO_18_R1_2004_04_Track04_wav.midi (238/500)
# Processing: MIDI-UNPROCESSED_19-20_R1_2014_MID--AUDIO_20_R1_2014_wav--1.midi (239/500)
# Processing: MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_13_R2_2015_wav--4.midi (240/500)
# Processing: MIDI-Unprocessed_11_R1_2011_MID--AUDIO_R1-D4_09_Track09_wav.midi (241/500)
# Processing: MIDI-Unprocessed_17_R1_2011_MID--AUDIO_R1-D7_03_Track03_wav.midi (242/500)
# Processing: MIDI-Unprocessed_14_R1_2009_01-05_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_04_WAV.midi (243/500)
# Processing: MIDI-Unprocessed_Recital8_MID--AUDIO_08_R1_2018_wav--2.midi (244/500)
# Processing: MIDI-UNPROCESSED_09-10_R1_2014_MID--AUDIO_09_R1_2014_wav--4.midi (245/500)
# Processing: MIDI-Unprocessed_045_PIANO045_MID--AUDIO-split_07-06-17_Piano-e_2-01_wav--4.midi (246/500)
# Processing: MIDI-Unprocessed_06_R1_2009_01-02_ORIG_MID--AUDIO_06_R1_2009_06_R1_2009_02_WAV.midi (247/500)
# Processing: ORIG-MIDI_02_7_6_13_Group__MID--AUDIO_05_R1_2013_wav--2.midi (248/500)
# Processing: MIDI-Unprocessed_XP_03_R1_2004_01-02_ORIG_MID--AUDIO_03_R1_2004_01_Track01_wav.midi (249/500)
# Processing: MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_16_R1_2015_wav--3.midi (250/500)
# Processing: MIDI-Unprocessed_15_R1_2009_03-06_ORIG_MID--AUDIO_15_R1_2009_15_R1_2009_06_WAV.midi (251/500)
# Processing: MIDI-Unprocessed_14_R1_2011_MID--AUDIO_R1-D6_02_Track02_wav.midi (252/500)
# Processing: ORIG-MIDI_01_7_6_13_Group__MID--AUDIO_04_R1_2013_wav--2.midi (253/500)
# Processing: MIDI-Unprocessed_050_PIANO050_MID--AUDIO-split_07-06-17_Piano-e_3-01_wav--1.midi (254/500)
# Processing: MIDI-Unprocessed_05_R1_2011_MID--AUDIO_R1-D2_09_Track09_wav.midi (255/500)
# Processing: MIDI-Unprocessed_17_R1_2008_01-04_ORIG_MID--AUDIO_17_R1_2008_wav--4.midi (256/500)
# Processing: MIDI-Unprocessed_10_R2_2011_MID--AUDIO_R2-D3_10_Track10_wav.midi (257/500)
# Processing: MIDI-Unprocessed_074_PIANO074_MID--AUDIO-split_07-08-17_Piano-e_2-04_wav--2.midi (258/500)
# Processing: MIDI-Unprocessed_25_R3_2011_MID--AUDIO_R3-D9_03_Track03_wav.midi (259/500)
# Processing: MIDI-Unprocessed_03_R3_2011_MID--AUDIO_R3-D1_04_Track04_wav.midi (260/500)
# Processing: ORIG-MIDI_01_7_8_13_Group__MID--AUDIO_04_R2_2013_wav--1.midi (261/500)
# Processing: MIDI-Unprocessed_16_R1_2008_01-04_ORIG_MID--AUDIO_16_R1_2008_wav--2.midi (262/500)
# Processing: MIDI-Unprocessed_Schubert10-12_MID--AUDIO_17_R2_2018_wav.midi (263/500)
# Processing: MIDI-Unprocessed_09_R1_2009_01-04_ORIG_MID--AUDIO_09_R1_2009_09_R1_2009_02_WAV.midi (264/500)
# Processing: MIDI-Unprocessed_054_PIANO054_MID--AUDIO-split_07-07-17_Piano-e_1-02_wav--3.midi (265/500)
# Processing: MIDI-Unprocessed_20_R1_2011_MID--AUDIO_R1-D8_04_Track04_wav.midi (266/500)
# Processing: MIDI-Unprocessed_Recital4_MID--AUDIO_04_R1_2018_wav--4.midi (267/500)
# Processing: MIDI-Unprocessed_Recital17-19_MID--AUDIO_19_R1_2018_wav--4.midi (268/500)
# Processing: MIDI-UNPROCESSED_19-20_R1_2014_MID--AUDIO_19_R1_2014_wav--1.midi (269/500)
# Processing: MIDI-Unprocessed_05_R1_2008_01-04_ORIG_MID--AUDIO_05_R1_2008_wav--3.midi (270/500)
# Processing: MIDI-Unprocessed_03_R1_2011_MID--AUDIO_R1-D1_19_Track19_wav.midi (271/500)
# Processing: MIDI-Unprocessed_22_R2_2011_MID--AUDIO_R2-D5_10_Track10_wav.midi (272/500)
# Processing: MIDI-UNPROCESSED_04-05_R1_2014_MID--AUDIO_04_R1_2014_wav--4.midi (273/500)
# Processing: MIDI-Unprocessed_23_R1_2006_01-05_ORIG_MID--AUDIO_23_R1_2006_02_Track02_wav.midi (274/500)
# Processing: MIDI-Unprocessed_Recital4_MID--AUDIO_04_R1_2018_wav--5.midi (275/500)
# Processing: MIDI-Unprocessed_XP_14_R1_2004_04_ORIG_MID--AUDIO_14_R1_2004_05_Track05_wav.midi (276/500)
# Processing: ORIG-MIDI_02_7_7_13_Group__MID--AUDIO_18_R1_2013_wav--3.midi (277/500)
# Processing: MIDI-Unprocessed_044_PIANO044_MID--AUDIO-split_07-06-17_Piano-e_1-04_wav--3.midi (278/500)
# Processing: ORIG-MIDI_02_7_6_13_Group__MID--AUDIO_07_R1_2013_wav--2.midi (279/500)
# Processing: MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_13_R1_2015_wav--5.midi (280/500)
# Processing: MIDI-Unprocessed_07_R2_2006_01_ORIG_MID--AUDIO_07_R2_2006_03_Track03_wav.midi (281/500)
# Processing: MIDI-Unprocessed_03_R1_2011_MID--AUDIO_R1-D1_15_Track15_wav.midi (282/500)
# Processing: MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_03_R1_2015_wav--1.midi (283/500)
# Processing: MIDI-Unprocessed_23_R2_2011_MID--AUDIO_R2-D6_03_Track03_wav.midi (284/500)
# Processing: MIDI-Unprocessed_12_R3_2011_MID--AUDIO_R3-D4_04_Track04_wav.midi (285/500)
# Processing: ORIG-MIDI_03_7_10_13_Group_MID--AUDIO_17_R3_2013_wav--3.midi (286/500)
# Processing: MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_02_R1_2015_wav--2.midi (287/500)
# Processing: MIDI-Unprocessed_R2_D1-2-3-6-7-8-11_mid--AUDIO-from_mp3_06_R2_2015_wav--4.midi (288/500)
# Processing: MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_04_R1_2015_wav--2.midi (289/500)
# Processing: MIDI-Unprocessed_Recital5-7_MID--AUDIO_07_R1_2018_wav--2.midi (290/500)
# Processing: ORIG-MIDI_02_7_10_13_Group_MID--AUDIO_12_R3_2013_wav--4.midi (291/500)
# Processing: MIDI-Unprocessed_03_R1_2011_MID--AUDIO_R1-D1_16_Track16_wav.midi (292/500)
# Processing: MIDI-Unprocessed_09_R1_2006_01-04_ORIG_MID--AUDIO_09_R1_2006_01_Track01_wav.midi (293/500)
# Processing: MIDI-Unprocessed_055_PIANO055_MID--AUDIO-split_07-07-17_Piano-e_1-04_wav--1.midi (294/500)
# Processing: MIDI-Unprocessed_07_R3_2008_01-05_ORIG_MID--AUDIO_07_R3_2008_wav--4.midi (295/500)
# Processing: MIDI-Unprocessed_SMF_12_01_2004_01-05_ORIG_MID--AUDIO_12_R1_2004_08_Track08_wav.midi (296/500)
# Processing: MIDI-Unprocessed_059_PIANO059_MID--AUDIO-split_07-07-17_Piano-e_2-03_wav--1.midi (297/500)
# Processing: MIDI-Unprocessed_15_R2_2008_01-04_ORIG_MID--AUDIO_15_R2_2008_wav--2.midi (298/500)
# Processing: MIDI-Unprocessed_07_R1_2008_01-04_ORIG_MID--AUDIO_07_R1_2008_wav--2.midi (299/500)
# Processing: MIDI-Unprocessed_08_R1_2009_01-04_ORIG_MID--AUDIO_08_R1_2009_08_R1_2009_03_WAV.midi (300/500)
# Processing: MIDI-Unprocessed_043_PIANO043_MID--AUDIO-split_07-06-17_Piano-e_1-03_wav--4.midi (301/500)
# Processing: MIDI-Unprocessed_23_R1_2011_MID--AUDIO_R1-D9_04_Track04_wav.midi (302/500)
# Processing: MIDI-Unprocessed_09_R3_2008_01-07_ORIG_MID--AUDIO_09_R3_2008_wav--7.midi (303/500)
# Processing: MIDI-Unprocessed_07_R2_2008_01-05_ORIG_MID--AUDIO_07_R2_2008_wav--4.midi (304/500)
# Processing: MIDI-Unprocessed_06_R1_2006_01-04_ORIG_MID--AUDIO_06_R1_2006_04_Track04_wav.midi (305/500)
# Processing: MIDI-UNPROCESSED_11-13_R1_2014_MID--AUDIO_11_R1_2014_wav--3.midi (306/500)
# Processing: MIDI-Unprocessed_05_R1_2011_MID--AUDIO_R1-D2_12_Track12_wav.midi (307/500)
# Processing: MIDI-Unprocessed_SMF_17_R1_2004_03-06_ORIG_MID--AUDIO_20_R2_2004_08_Track08_wav.midi (308/500)
# Processing: MIDI-Unprocessed_Recital17-19_MID--AUDIO_18_R1_2018_wav--2.midi (309/500)
# Processing: ORIG-MIDI_02_7_8_13_Group__MID--AUDIO_08_R2_2013_wav--3.midi (310/500)
# Processing: MIDI-Unprocessed_R2_D1-2-3-6-7-8-11_mid--AUDIO-from_mp3_08_R2_2015_wav--1.midi (311/500)
# Processing: MIDI-Unprocessed_17_R1_2006_01-06_ORIG_MID--AUDIO_17_R1_2006_02_Track02_wav.midi (312/500)
# Processing: MIDI-UNPROCESSED_19-20-21_R2_2014_MID--AUDIO_19_R2_2014_wav.midi (313/500)
# Processing: MIDI-Unprocessed_03_R1_2008_01-04_ORIG_MID--AUDIO_03_R1_2008_wav--2.midi (314/500)
# Processing: MIDI-Unprocessed_21_R1_2011_MID--AUDIO_R1-D8_07_Track07_wav.midi (315/500)
# Processing: MIDI-Unprocessed_071_PIANO071_MID--AUDIO-split_07-08-17_Piano-e_1-04_wav--3.midi (316/500)
# Processing: MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-from_mp3_11_R1_2015_wav--3.midi (317/500)
# Processing: MIDI-UNPROCESSED_01-03_R1_2014_MID--AUDIO_03_R1_2014_wav--5.midi (318/500)
# Processing: MIDI-Unprocessed_08_R1_2011_MID--AUDIO_R1-D3_09_Track09_wav.midi (319/500)
# Processing: MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_04_R1_2015_wav--4.midi (320/500)
# Processing: MIDI-Unprocessed_16_R1_2008_01-04_ORIG_MID--AUDIO_16_R1_2008_wav--1.midi (321/500)
# Processing: MIDI-Unprocessed_11_R1_2011_MID--AUDIO_R1-D4_08_Track08_wav.midi (322/500)
# Processing: MIDI-Unprocessed_22_R2_2011_MID--AUDIO_R2-D5_11_Track11_wav.midi (323/500)
# Processing: ORIG-MIDI_01_7_7_13_Group__MID--AUDIO_14_R1_2013_wav--2.midi (324/500)
# Processing: MIDI-UNPROCESSED_19-20_R1_2014_MID--AUDIO_19_R1_2014_wav--8.midi (325/500)
# Processing: ORIG-MIDI_01_7_6_13_Group__MID--AUDIO_04_R1_2013_wav--4.midi (326/500)
# Processing: MIDI-Unprocessed_06_R2_2008_01-05_ORIG_MID--AUDIO_06_R2_2008_wav--4.midi (327/500)
# Processing: MIDI-UNPROCESSED_16-18_R1_2014_MID--AUDIO_16_R1_2014_wav--2.midi (328/500)
# Processing: MIDI-Unprocessed_XP_11_R1_2004_01-02_ORIG_MID--AUDIO_11_R1_2004_01_Track01_wav.midi (329/500)
# Processing: MIDI-Unprocessed_10_R1_2006_01-04_ORIG_MID--AUDIO_10_R1_2006_02_Track02_wav.midi (330/500)
# Processing: MIDI-Unprocessed_Recital13-15_MID--AUDIO_14_R1_2018_wav--3.midi (331/500)
# Processing: MIDI-Unprocessed_Recital17-19_MID--AUDIO_17_R1_2018_wav--3.midi (332/500)
# Processing: MIDI-Unprocessed_09_R1_2006_01-04_ORIG_MID--AUDIO_09_R1_2006_02_Track02_wav.midi (333/500)
# Processing: ORIG-MIDI_01_7_8_13_Group__MID--AUDIO_02_R2_2013_wav--1.midi (334/500)
# Processing: MIDI-Unprocessed_02_R1_2008_01-05_ORIG_MID--AUDIO_02_R1_2008_wav--4.midi (335/500)
# Processing: ORIG-MIDI_03_7_6_13_Group__MID--AUDIO_10_R1_2013_wav--2.midi (336/500)
# Processing: MIDI-Unprocessed_01_R1_2006_01-09_ORIG_MID--AUDIO_01_R1_2006_01_Track01_wav.midi (337/500)
# Processing: MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_18_R1_2015_wav--2.midi (338/500)
# Processing: MIDI-Unprocessed_058_PIANO058_MID--AUDIO-split_07-07-17_Piano-e_2-02_wav--2.midi (339/500)
# Processing: MIDI-Unprocessed_Schubert7-9_MID--AUDIO_15_R2_2018_wav.midi (340/500)
# Processing: MIDI-Unprocessed_17_R2_2011_MID--AUDIO_R2-D5_03_Track03_wav.midi (341/500)
# Processing: MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_01_R1_2015_wav--5.midi (342/500)
# Processing: MIDI-Unprocessed_17_R1_2011_MID--AUDIO_R1-D7_05_Track05_wav.midi (343/500)
# Processing: MIDI-Unprocessed_083_PIANO083_MID--AUDIO-split_07-09-17_Piano-e_2_-06_wav--2.midi (344/500)
# Processing: MIDI-Unprocessed_04_R3_2011_MID--AUDIO_R3-D2_05_Track05_wav.midi (345/500)
# Processing: ORIG-MIDI_02_7_6_13_Group__MID--AUDIO_06_R1_2013_wav--3.midi (346/500)
# Processing: MIDI-Unprocessed_18_R1_2006_01-05_ORIG_MID--AUDIO_18_R1_2006_04_Track04_wav.midi (347/500)
# Processing: MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_14_R1_2015_wav--4.midi (348/500)
# Processing: MIDI-Unprocessed_02_R3_2008_01-03_ORIG_MID--AUDIO_02_R3_2008_wav--3.midi (349/500)
# Processing: ORIG-MIDI_01_7_7_13_Group__MID--AUDIO_13_R1_2013_wav--4.midi (350/500)
# Processing: MIDI-Unprocessed_043_PIANO043_MID--AUDIO-split_07-06-17_Piano-e_1-03_wav--3.midi (351/500)
# Processing: MIDI-Unprocessed_045_PIANO045_MID--AUDIO-split_07-06-17_Piano-e_2-01_wav--1.midi (352/500)
# Processing: MIDI-Unprocessed_07_R1_2011_MID--AUDIO_R1-D3_03_Track03_wav.midi (353/500)
# Processing: MIDI-Unprocessed_Schubert7-9_MID--AUDIO_11_R2_2018_wav.midi (354/500)
# Processing: MIDI-UNPROCESSED_09-10_R1_2014_MID--AUDIO_10_R1_2014_wav--4.midi (355/500)
# Processing: MIDI-Unprocessed_12_R2_2009_01_ORIG_MID--AUDIO_12_R2_2009_12_R2_2009_04_WAV.midi (356/500)
# Processing: MIDI-Unprocessed_13_R1_2011_MID--AUDIO_R1-D5_03_Track03_wav.midi (357/500)
# Processing: ORIG-MIDI_03_7_8_13_Group__MID--AUDIO_19_R2_2013_wav--4.midi (358/500)
# Processing: MIDI-Unprocessed_XP_09_R1_2004_01-02_ORIG_MID--AUDIO_09_R1_2004_02_Track02_wav.midi (359/500)
# Processing: MIDI-Unprocessed_Recital17-19_MID--AUDIO_19_R1_2018_wav--2.midi (360/500)
# Processing: MIDI-Unprocessed_081_PIANO081_MID--AUDIO-split_07-09-17_Piano-e_2_-02_wav--3.midi (361/500)
# Processing: ORIG-MIDI_02_7_6_13_Group__MID--AUDIO_06_R1_2013_wav--4.midi (362/500)
# Processing: MIDI-Unprocessed_02_R3_2008_01-03_ORIG_MID--AUDIO_02_R3_2008_wav--1.midi (363/500)
# Processing: MIDI-Unprocessed_02_R1_2008_01-05_ORIG_MID--AUDIO_02_R1_2008_wav--2.midi (364/500)
# Processing: MIDI-Unprocessed_050_PIANO050_MID--AUDIO-split_07-06-17_Piano-e_3-01_wav--3.midi (365/500)
# Processing: MIDI-UNPROCESSED_09-10_R1_2014_MID--AUDIO_09_R1_2014_wav--3.midi (366/500)
# Processing: MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_15_R2_2015_wav--2.midi (367/500)
# Processing: MIDI-Unprocessed_058_PIANO058_MID--AUDIO-split_07-07-17_Piano-e_2-02_wav--1.midi (368/500)
# Processing: MIDI-Unprocessed_08_R1_2008_01-05_ORIG_MID--AUDIO_08_R1_2008_wav--1.midi (369/500)
# Processing: MIDI-UNPROCESSED_04-05_R1_2014_MID--AUDIO_05_R1_2014_wav--1.midi (370/500)
# Processing: MIDI-Unprocessed_XP_16_R2_2004_01_ORIG_MID--AUDIO_16_R2_2004_04_Track04_wav.midi (371/500)
# Processing: MIDI-Unprocessed_R2_D2-19-21-22_mid--AUDIO-from_mp3_19_R2_2015_wav--2.midi (372/500)
# Processing: MIDI-Unprocessed_R2_D1-2-3-6-7-8-11_mid--AUDIO-from_mp3_07_R2_2015_wav--3.midi (373/500)
# Processing: MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-from_mp3_10_R1_2015_wav--1.midi (374/500)
# Processing: MIDI-Unprocessed_19_R1_2011_MID--AUDIO_R1-D7_13_Track13_wav.midi (375/500)
# Processing: MIDI-UNPROCESSED_14-15_R1_2014_MID--AUDIO_15_R1_2014_wav--4.midi (376/500)
# Processing: MIDI-Unprocessed_SMF_16_R1_2004_01-08_ORIG_MID--AUDIO_16_R1_2004_04_Track04_wav.midi (377/500)
# Processing: MIDI-Unprocessed_XP_14_R1_2004_04_ORIG_MID--AUDIO_14_R1_2004_06_Track06_wav.midi (378/500)
# Processing: MIDI-Unprocessed_Chamber5_MID--AUDIO_18_R3_2018_wav--1.midi (379/500)
# Processing: MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_06_R1_2015_wav--5.midi (380/500)
# Processing: MIDI-Unprocessed_079_PIANO079_MID--AUDIO-split_07-09-17_Piano-e_1-04_wav--1.midi (381/500)
# Processing: MIDI-UNPROCESSED_16-18_R1_2014_MID--AUDIO_18_R1_2014_wav--4.midi (382/500)
# Processing: ORIG-MIDI_01_7_10_13_Group_MID--AUDIO_08_R3_2013_wav--3.midi (383/500)
# Processing: MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_20_R1_2015_wav--1.midi (384/500)
# Processing: MIDI-Unprocessed_XP_06_R1_2004_01_ORIG_MID--AUDIO_06_R1_2004_01_Track01_wav.midi (385/500)
# Processing: MIDI-UNPROCESSED_16-18_R1_2014_MID--AUDIO_18_R1_2014_wav--5.midi (386/500)
# Processing: MIDI-Unprocessed_08_R1_2009_01-04_ORIG_MID--AUDIO_08_R1_2009_08_R1_2009_02_WAV.midi (387/500)
# Processing: ORIG-MIDI_02_7_6_13_Group__MID--AUDIO_06_R1_2013_wav--1.midi (388/500)
# Processing: MIDI-Unprocessed_17_R1_2006_01-06_ORIG_MID--AUDIO_17_R1_2006_04_Track04_wav.midi (389/500)
# Processing: ORIG-MIDI_01_7_6_13_Group__MID--AUDIO_02_R1_2013_wav--4.midi (390/500)
# Processing: MIDI-Unprocessed_067_PIANO067_MID--AUDIO-split_07-07-17_Piano-e_3-03_wav--1.midi (391/500)
# Processing: MIDI-Unprocessed_062_PIANO062_MID--AUDIO-split_07-07-17_Piano-e_2-07_wav--2.midi (392/500)
# Processing: MIDI-Unprocessed_053_PIANO053_MID--AUDIO-split_07-06-17_Piano-e_3-04_wav--4.midi (393/500)
# Processing: MIDI-Unprocessed_16_R1_2011_MID--AUDIO_R1-D6_12_Track12_wav.midi (394/500)
# Processing: MIDI-Unprocessed_XP_17_R2_2004_01_ORIG_MID--AUDIO_17_R2_2004_01_Track01_wav.midi (395/500)
# Processing: MIDI-UNPROCESSED_11-13_R1_2014_MID--AUDIO_13_R1_2014_wav--1.midi (396/500)
# Processing: MIDI-Unprocessed_SMF_05_R1_2004_01_ORIG_MID--AUDIO_05_R1_2004_03_Track03_wav.midi (397/500)
# Processing: MIDI-Unprocessed_17_R3_2011_MID--AUDIO_R3-D6_08_Track08_wav.midi (398/500)
# Processing: MIDI-UNPROCESSED_01-03_R1_2014_MID--AUDIO_01_R1_2014_wav--3.midi (399/500)
# Processing: MIDI-Unprocessed_Recital17-19_MID--AUDIO_19_R1_2018_wav--1.midi (400/500)
# Processing: MIDI-Unprocessed_057_PIANO057_MID--AUDIO-split_07-07-17_Piano-e_1-07_wav--1.midi (401/500)
# Processing: MIDI-Unprocessed_19_R1_2011_MID--AUDIO_R1-D7_12_Track12_wav.midi (402/500)
# Processing: ORIG-MIDI_02_7_7_13_Group__MID--AUDIO_19_R1_2013_wav--2.midi (403/500)
# Processing: MIDI-Unprocessed_057_PIANO057_MID--AUDIO-split_07-07-17_Piano-e_1-07_wav--2.midi (404/500)
# Processing: ORIG-MIDI_02_7_7_13_Group__MID--AUDIO_17_R1_2013_wav--3.midi (405/500)
# Processing: MIDI-Unprocessed_SMF_12_01_2004_01-05_ORIG_MID--AUDIO_12_R1_2004_09_Track09_wav.midi (406/500)
# Processing: MIDI-Unprocessed_11_R1_2009_01-05_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_03_WAV.midi (407/500)
# Processing: MIDI-UNPROCESSED_14-15_R1_2014_MID--AUDIO_15_R1_2014_wav--5.midi (408/500)
# Processing: MIDI-Unprocessed_Recital17-19_MID--AUDIO_17_R1_2018_wav--2.midi (409/500)
# Processing: MIDI-Unprocessed_066_PIANO066_MID--AUDIO-split_07-07-17_Piano-e_3-02_wav--1.midi (410/500)
# Processing: MIDI-Unprocessed_03_R1_2011_MID--AUDIO_R1-D1_18_Track18_wav.midi (411/500)
# Processing: MIDI-Unprocessed_06_R1_2008_01-04_ORIG_MID--AUDIO_06_R1_2008_wav--2.midi (412/500)
# Processing: ORIG-MIDI_02_7_10_13_Group_MID--AUDIO_12_R3_2013_wav--2.midi (413/500)
# Processing: MIDI-Unprocessed_23_R3_2011_MID--AUDIO_R3-D8_04_Track04_wav.midi (414/500)
# Processing: MIDI-Unprocessed_070_PIANO070_MID--AUDIO-split_07-08-17_Piano-e_1-02_wav--3.midi (415/500)
# Processing: MIDI-Unprocessed_12_R2_2011_MID--AUDIO_R2-D4_02_Track02_wav.midi (416/500)
# Processing: MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-from_mp3_09_R1_2015_wav--4.midi (417/500)
# Processing: MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_15_R2_2015_wav--1.midi (418/500)
# Processing: MIDI-Unprocessed_07_R3_2008_01-05_ORIG_MID--AUDIO_07_R3_2008_wav--1.midi (419/500)
# Processing: MIDI-Unprocessed_13_R1_2006_01-06_ORIG_MID--AUDIO_13_R1_2006_02_Track02_wav.midi (420/500)
# Processing: MIDI-Unprocessed_073_PIANO073_MID--AUDIO-split_07-08-17_Piano-e_2-02_wav--1.midi (421/500)
# Processing: MIDI-Unprocessed_Recital13-15_MID--AUDIO_14_R1_2018_wav--2.midi (422/500)
# Processing: MIDI-Unprocessed_07_R2_2008_01-05_ORIG_MID--AUDIO_07_R2_2008_wav--2.midi (423/500)
# Processing: MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-from_mp3_11_R1_2015_wav--1.midi (424/500)
# Processing: MIDI-Unprocessed_XP_19_R1_2004_01-02_ORIG_MID--AUDIO_19_R1_2004_03_Track03_wav.midi (425/500)
# Processing: ORIG-MIDI_01_7_6_13_Group__MID--AUDIO_01_R1_2013_wav--2.midi (426/500)
# Processing: MIDI-Unprocessed_R2_D1-2-3-6-7-8-11_mid--AUDIO-from_mp3_11_R2_2015_wav--1.midi (427/500)
# Processing: MIDI-Unprocessed_05_R1_2008_01-04_ORIG_MID--AUDIO_05_R1_2008_wav--2.midi (428/500)
# Processing: MIDI-Unprocessed_081_PIANO081_MID--AUDIO-split_07-09-17_Piano-e_2_-02_wav--4.midi (429/500)
# Processing: MIDI-Unprocessed_04_R2_2011_MID--AUDIO_R2-D2_03_Track03_wav.midi (430/500)
# Processing: MIDI-Unprocessed_01_R2_2006_01_ORIG_MID--AUDIO_01_R2_2006_02_Track02_wav.midi (431/500)
# Processing: MIDI-Unprocessed_Recital1-3_MID--AUDIO_01_R1_2018_wav--1.midi (432/500)
# Processing: MIDI-Unprocessed_Recital13-15_MID--AUDIO_14_R1_2018_wav--1.midi (433/500)
# Processing: MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_08_R1_2015_wav--4.midi (434/500)
# Processing: MIDI-Unprocessed_09_R3_2008_01-07_ORIG_MID--AUDIO_09_R3_2008_wav--5.midi (435/500)
# Processing: MIDI-Unprocessed_08_R1_2006_01-04_ORIG_MID--AUDIO_08_R1_2006_Disk1_02_Track02_wav.midi (436/500)
# Processing: ORIG-MIDI_01_7_8_13_Group__MID--AUDIO_02_R2_2013_wav--5.midi (437/500)
# Processing: MIDI-Unprocessed_SMF_16_R1_2004_01-08_ORIG_MID--AUDIO_16_R1_2004_03_Track03_wav.midi (438/500)
# Processing: MIDI-Unprocessed_04_R2_2008_01-04_ORIG_MID--AUDIO_04_R2_2008_wav--1.midi (439/500)
# Processing: MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_16_R1_2015_wav--1.midi (440/500)
# Processing: MIDI-Unprocessed_Recital1-3_MID--AUDIO_02_R1_2018_wav--3.midi (441/500)
# Processing: MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_02_R1_2015_wav--1.midi (442/500)
# Processing: ORIG-MIDI_01_7_7_13_Group__MID--AUDIO_13_R1_2013_wav--2.midi (443/500)
# Processing: ORIG-MIDI_02_7_7_13_Group__MID--AUDIO_15_R1_2013_wav--3.midi (444/500)
# Processing: MIDI-Unprocessed_09_R2_2006_01_ORIG_MID--AUDIO_09_R2_2006_02_Track02_wav.midi (445/500)
# Processing: MIDI-Unprocessed_20_R1_2009_06-07_ORIG_MID--AUDIO_20_R1_2009_20_R1_2009_06_WAV.midi (446/500)
# Processing: MIDI-Unprocessed_17_R2_2011_MID--AUDIO_R2-D5_04_Track04_wav.midi (447/500)
# Processing: ORIG-MIDI_02_7_7_13_Group__MID--AUDIO_17_R1_2013_wav--2.midi (448/500)
# Processing: MIDI-Unprocessed_Schubert4-6_MID--AUDIO_08_R2_2018_wav.midi (449/500)
# Processing: MIDI-Unprocessed_13_R1_2008_01-04_ORIG_MID--AUDIO_13_R1_2008_wav--1.midi (450/500)
# Processing: MIDI-Unprocessed_19_R1_2006_01-07_ORIG_MID--AUDIO_19_R1_2006_03_Track03_wav.midi (451/500)
# Processing: MIDI-UNPROCESSED_01-03_R1_2014_MID--AUDIO_03_R1_2014_wav--3.midi (452/500)
# Processing: ORIG-MIDI_01_7_6_13_Group__MID--AUDIO_03_R1_2013_wav--3.midi (453/500)
# Processing: ORIG-MIDI_02_7_8_13_Group__MID--AUDIO_12_R2_2013_wav--2.midi (454/500)
# Processing: ORIG-MIDI_02_7_8_13_Group__MID--AUDIO_12_R2_2013_wav--3.midi (455/500)
# Processing: MIDI-Unprocessed_17_R1_2008_01-04_ORIG_MID--AUDIO_17_R1_2008_wav--2.midi (456/500)
# Processing: MIDI-Unprocessed_08_R2_2006_01_ORIG_MID--AUDIO_08_R2_2006_03_Track03_wav.midi (457/500)
# Processing: MIDI-Unprocessed_25_R2_2011_MID--AUDIO_R2-D6_07_Track07_wav.midi (458/500)
# Processing: MIDI-Unprocessed_07_R1_2009_01-03_ORIG_MID--AUDIO_07_R1_2009_07_R1_2009_02_WAV.midi (459/500)
# Processing: MIDI-Unprocessed_Recital9-11_MID--AUDIO_09_R1_2018_wav--5.midi (460/500)
# Processing: MIDI-Unprocessed_09_R1_2008_01-05_ORIG_MID--AUDIO_09_R1_2008_wav--1.midi (461/500)
# Processing: MIDI-Unprocessed_02_R1_2008_01-05_ORIG_MID--AUDIO_02_R1_2008_wav--5.midi (462/500)
# Processing: MIDI-Unprocessed_Recital16_MID--AUDIO_16_R1_2018_wav--2.midi (463/500)
# Processing: MIDI-Unprocessed_Recital17-19_MID--AUDIO_17_R1_2018_wav--4.midi (464/500)
# Processing: MIDI-Unprocessed_078_PIANO078_MID--AUDIO-split_07-09-17_Piano-e_1-02_wav--1.midi (465/500)
# Processing: MIDI-Unprocessed_17_R1_2011_MID--AUDIO_R1-D7_04_Track04_wav.midi (466/500)
# Processing: MIDI-Unprocessed_05_R2_2006_01_ORIG_MID--AUDIO_05_R2_2006_01_Track01_wav.midi (467/500)
# Processing: MIDI-Unprocessed_08_R1_2011_MID--AUDIO_R1-D3_07_Track07_wav.midi (468/500)
# Processing: ORIG-MIDI_01_7_6_13_Group__MID--AUDIO_04_R1_2013_wav--1.midi (469/500)
# Processing: MIDI-Unprocessed_09_R2_2009_01_ORIG_MID--AUDIO_09_R2_2009_09_R2_2009_02_WAV.midi (470/500)
# Processing: MIDI-Unprocessed_01_R1_2011_MID--AUDIO_R1-D1_05_Track05_wav.midi (471/500)
# Processing: MIDI-UNPROCESSED_21-22_R1_2014_MID--AUDIO_21_R1_2014_wav--1.midi (472/500)
# Processing: MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_13_R2_2015_wav--1.midi (473/500)
# Processing: MIDI-Unprocessed_13_R1_2008_01-04_ORIG_MID--AUDIO_13_R1_2008_wav--4.midi (474/500)
# Processing: MIDI-Unprocessed_06_R1_2008_01-04_ORIG_MID--AUDIO_06_R1_2008_wav--3.midi (475/500)
# Processing: MIDI-Unprocessed_09_R1_2011_MID--AUDIO_R1-D3_13_Track13_wav.midi (476/500)
# Processing: MIDI-Unprocessed_03_R1_2009_03-08_ORIG_MID--AUDIO_03_R1_2009_03_R1_2009_03_WAV.midi (477/500)
# Processing: MIDI-Unprocessed_XP_04_R1_2004_06_ORIG_MID--AUDIO_04_R1_2004_08_Track08_wav.midi (478/500)
# Processing: MIDI-Unprocessed_Recital17-19_MID--AUDIO_17_R1_2018_wav--1.midi (479/500)
# Processing: MIDI-Unprocessed_11_R1_2008_01-04_ORIG_MID--AUDIO_11_R1_2008_wav--2.midi (480/500)
# Processing: MIDI-Unprocessed_06_R2_2011_MID--AUDIO_R2-D2_07_Track07_wav.midi (481/500)
# Processing: MIDI-Unprocessed_24_R1_2006_01-05_ORIG_MID--AUDIO_24_R1_2006_03_Track03_wav.midi (482/500)
# Processing: MIDI-Unprocessed_18_R1_2011_MID--AUDIO_R1-D7_07_Track07_wav.midi (483/500)
# Processing: ORIG-MIDI_01_7_7_13_Group__MID--AUDIO_12_R1_2013_wav--1.midi (484/500)
# Processing: MIDI-Unprocessed_10_R1_2008_01-04_ORIG_MID--AUDIO_10_R1_2008_wav--4.midi (485/500)
# Processing: MIDI-Unprocessed_Recital9-11_MID--AUDIO_11_R1_2018_wav--1.midi (486/500)
# Processing: ORIG-MIDI_02_7_8_13_Group__MID--AUDIO_11_R2_2013_wav--1.midi (487/500)
# Processing: ORIG-MIDI_03_7_8_13_Group__MID--AUDIO_15_R2_2013_wav--1.midi (488/500)
# Processing: MIDI-Unprocessed_XP_06_R2_2004_01_ORIG_MID--AUDIO_06_R2_2004_03_Track03_wav.midi (489/500)
# Processing: MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_06_R1_2015_wav--3.midi (490/500)
# Processing: MIDI-Unprocessed_06_R1_2006_01-04_ORIG_MID--AUDIO_06_R1_2006_02_Track02_wav.midi (491/500)
# Processing: MIDI-Unprocessed_XP_18_R1_2004_01-02_ORIG_MID--AUDIO_18_R1_2004_03_Track03_wav.midi (492/500)
# Processing: ORIG-MIDI_01_7_7_13_Group__MID--AUDIO_11_R1_2013_wav--1.midi (493/500)
# Processing: ORIG-MIDI_01_7_10_13_Group_MID--AUDIO_08_R3_2013_wav--2.midi (494/500)
# Processing: MIDI-Unprocessed_07_R1_2008_01-04_ORIG_MID--AUDIO_07_R1_2008_wav--1.midi (495/500)
# Processing: MIDI-Unprocessed_09_R1_2011_MID--AUDIO_R1-D3_14_Track14_wav.midi (496/500)
# Processing: MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_05_R1_2015_wav--3.midi (497/500)
# Processing: MIDI-Unprocessed_SMF_13_01_2004_01-05_ORIG_MID--AUDIO_13_R1_2004_12_Track12_wav.midi (498/500)
# Processing: MIDI-Unprocessed_08_R1_2006_01-04_ORIG_MID--AUDIO_08_R1_2006_Disk1_01_Track01_wav.midi (499/500)
# Processing: MIDI-Unprocessed_083_PIANO083_MID--AUDIO-split_07-09-17_Piano-e_2_-06_wav--5.midi (500/500)
# Training completed on 500 files
# Learned 267626 trigram patterns
# Total notes processed: 2683354
# Octave distribution in training data:
#   Octave 1: 747 notes (0.0%)
#   Octave 2: 61336 notes (2.3%)
#   Octave 3: 264431 notes (9.9%)
#   Octave 4: 635942 notes (23.7%)
#   Octave 5: 860064 notes (32.1%)
#   Octave 6: 626958 notes (23.4%)
#   Octave 7: 206623 notes (7.7%)
#   Octave 8: 27245 notes (1.0%)
#   Octave 9: 8 notes (0.0%)
# Generated MIDI saved as: task2.mid
# Total events: 1000
# Duration: ~175.0 beats
