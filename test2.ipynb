# %%
import os
import random
import pickle
from collections import defaultdict, Counter
import mido
from mido import MidiFile, MidiTrack, Message
import glob

class SymbolicMusicGenerator:
    def __init__(self):
        self.trigram_model = defaultdict(Counter)
        self.tempo_transitions = defaultdict(list)
        self.note_durations = defaultdict(list)
        self.velocity_patterns = defaultdict(list)
        self.time_signatures = []
        self.tempos = []
        
    def extract_musical_events(self, midi_file_path):
        """Extract musical events from a MIDI file including timing information"""
        try:
            mid = MidiFile(midi_file_path)
            events = []
            current_tempo = 500000  # Default tempo (120 BPM)
            current_time = 0
            
            # Track active notes for duration calculation
            active_notes = {}
            
            for track in mid.tracks:
                track_time = 0
                for msg in track:
                    track_time += msg.time
                    current_time = track_time
                    
                    if msg.type == 'set_tempo':
                        current_tempo = msg.tempo
                        events.append(('tempo', msg.tempo, current_time))
                        
                    elif msg.type == 'time_signature':
                        events.append(('time_sig', f"{msg.numerator}/{msg.denominator}", current_time))
                        
                    elif msg.type == 'note_on' and msg.velocity > 0:
                        note_key = (msg.channel, msg.note)
                        active_notes[note_key] = {
                            'start_time': current_time,
                            'velocity': msg.velocity,
                            'tempo': current_tempo
                        }
                        events.append(('note_on', msg.note, current_time, msg.velocity, current_tempo))
                        
                    elif msg.type == 'note_off' or (msg.type == 'note_on' and msg.velocity == 0):
                        note_key = (msg.channel, msg.note)
                        if note_key in active_notes:
                            note_info = active_notes[note_key]
                            duration = current_time - note_info['start_time']
                            events.append(('note_off', msg.note, current_time, duration, note_info['velocity']))
                            del active_notes[note_key]
            
            return events
            
        except Exception as e:
            print(f"Error processing {midi_file_path}: {e}")
            return []
    
    def create_symbolic_representation(self, events):
        """Convert events to symbolic representation for Markov chain"""
        symbols = []
        prev_time = 0
        
        # Filter and sort note events
        note_events = [(e[2], e) for e in events if e[0] == 'note_on']
        note_events.sort()  # Sort by time
        
        for time_pos, event in note_events:
            note = event[1]
            velocity = event[3]
            tempo = event[4]
            
            # Calculate time delta from previous note
            time_delta = max(0, time_pos - prev_time)
            prev_time = time_pos
            
            # Quantize timing to musical values (in ticks)
            if time_delta < 120:
                timing = "T1"  # Very short
            elif time_delta < 240:
                timing = "T2"  # Eighth note
            elif time_delta < 480:
                timing = "T3"  # Quarter note
            elif time_delta < 960:
                timing = "T4"  # Half note
            else:
                timing = "T5"  # Whole note or longer
            
            # Quantize velocity more musically
            if velocity < 40:
                vel_level = "pp"  # pianissimo
            elif velocity < 70:
                vel_level = "mp"  # mezzo-piano  
            elif velocity < 90:
                vel_level = "mf"  # mezzo-forte
            elif velocity < 110:
                vel_level = "f"   # forte
            else:
                vel_level = "ff"  # fortissimo
            
            # Use pitch classes and octaves for better musical coherence
            pitch_class = note % 12
            octave = note // 12
            
            # Create more musical symbol
            symbol = f"P{pitch_class}_O{octave}_{vel_level}_{timing}"
            symbols.append(symbol)
                
        return symbols
    
    def build_trigram_model(self, symbols):
        """Build trigram Markov chain from symbols"""
        for i in range(len(symbols) - 2):
            trigram_key = (symbols[i], symbols[i + 1])
            next_symbol = symbols[i + 2]
            self.trigram_model[trigram_key][next_symbol] += 1
    
    def train_on_dataset(self, dataset_path, max_files=50):
        """Train the model on MIDI files from the dataset"""
        print("Scanning for MIDI files...")
        midi_files = []
        
        # Recursively find all .mid files
        for root, dirs, files in os.walk(dataset_path):
            for file in files:
                if file.lower().endswith(('.mid', '.midi')):
                    midi_files.append(os.path.join(root, file))
        
        print(f"Found {len(midi_files)} MIDI files")
        
        # Limit the number of files to process for reasonable training time
        if len(midi_files) > max_files:
            midi_files = random.sample(midi_files, max_files)
            print(f"Processing {max_files} randomly selected files")
        
        processed_count = 0
        total_notes = 0
        octave_distribution = defaultdict(int)
        
        for midi_file in midi_files:
            print(f"Processing: {os.path.basename(midi_file)} ({processed_count + 1}/{len(midi_files)})")
            
            events = self.extract_musical_events(midi_file)
            if events:
                symbols = self.create_symbolic_representation(events)
                if len(symbols) > 10:  # Only use files with sufficient content
                    self.build_trigram_model(symbols)
                    
                    # Debug: track octave distribution
                    for symbol in symbols:
                        if symbol.startswith('P'):
                            try:
                                parts = symbol.split('_')
                                octave = int(parts[1][1:])
                                octave_distribution[octave] += 1
                                total_notes += 1
                            except:
                                pass
                    
                    # Store additional musical information
                    tempos = [e[1] for e in events if e[0] == 'tempo']
                    if tempos:
                        self.tempos.extend(tempos)
                        
                processed_count += 1
        
        print(f"Training completed on {processed_count} files")
        print(f"Learned {len(self.trigram_model)} trigram patterns")
        print(f"Total notes processed: {total_notes}")
        print("Octave distribution in training data:")
        for octave in sorted(octave_distribution.keys()):
            percentage = (octave_distribution[octave] / total_notes) * 100
            print(f"  Octave {octave}: {octave_distribution[octave]} notes ({percentage:.1f}%)")
    
    def generate_sequence(self, length=200, seed=None):
        """Generate a new sequence using the trigram model"""
        if len(self.trigram_model) == 0:
            raise ValueError("Model not trained yet!")
        
        # Start with a random trigram or use seed
        if seed and len(seed) >= 2:
            current_bigram = (seed[0], seed[1])
        else:
            current_bigram = random.choice(list(self.trigram_model.keys()))
        
        sequence = list(current_bigram)
        
        # Track musical context for better generation
        last_pitch_class = None
        last_octave = None
        octave_bias = 0  # Bias to encourage higher octaves
        
        for i in range(length - 2):
            if current_bigram in self.trigram_model:
                # Choose next symbol based on probability distribution
                next_symbols = self.trigram_model[current_bigram]
                total_count = sum(next_symbols.values())
                
                if total_count > 0:
                    # Create weighted list for better selection
                    weighted_choices = []
                    for symbol, count in next_symbols.items():
                        # Add some musical intelligence - prefer steps and skips
                        weight = count
                        if symbol.startswith('P') and last_pitch_class is not None:
                            try:
                                parts = symbol.split('_')
                                pitch_class = int(parts[0][1:])
                                octave = int(parts[1][1:])
                                
                                # Strongly favor higher octaves
                                if octave >= 5:
                                    weight = int(weight * 2.0)
                                elif octave >= 4:
                                    weight = int(weight * 1.5)
                                elif octave <= 2:
                                    weight = max(1, int(weight * 0.3))  # Heavily discourage low octaves
                                
                                # Slightly favor melodic intervals (steps and small skips)
                                interval = abs(pitch_class - last_pitch_class)
                                if interval <= 2 or interval >= 10:  # Steps (including octave wrapping)
                                    weight = int(weight * 1.2)
                                elif interval <= 4 or interval >= 8:  # Small skips
                                    weight = int(weight * 1.1)
                                
                                # Favor staying in similar octave range
                                if abs(octave - last_octave) <= 1:
                                    weight = int(weight * 1.1)
                                    
                                last_pitch_class = pitch_class
                                last_octave = octave
                            except:
                                pass
                        
                        weighted_choices.extend([symbol] * max(1, weight))
                    
                    if weighted_choices:
                        next_symbol = random.choice(weighted_choices)
                        sequence.append(next_symbol)
                        current_bigram = (current_bigram[1], next_symbol)
                    else:
                        # Fallback
                        current_bigram = random.choice(list(self.trigram_model.keys()))
                        sequence.extend(current_bigram)
                else:
                    # Fallback to random trigram
                    current_bigram = random.choice(list(self.trigram_model.keys()))
                    sequence.extend(current_bigram)
            else:
                # Start new random trigram
                current_bigram = random.choice(list(self.trigram_model.keys()))
                sequence.extend(current_bigram)
        
        return sequence
    
    def sequence_to_midi(self, sequence, output_path="generated_music.mid"):
        """Convert generated sequence back to MIDI file with proper timing"""
        mid = MidiFile(ticks_per_beat=480)
        track = MidiTrack()
        mid.tracks.append(track)
        
        # Set default tempo
        default_tempo = 500000 if not self.tempos else random.choice(self.tempos)
        track.append(mido.MetaMessage('set_tempo', tempo=int(default_tempo), time=0))
        
        # Add time signature
        track.append(mido.MetaMessage('time_signature', numerator=4, denominator=4, time=0))
        
        # Store events with absolute timing first
        events = []
        current_time = 0
        
        for i, symbol in enumerate(sequence):
            if symbol.startswith('P'):
                try:
                    parts = symbol.split('_')
                    if len(parts) >= 4:
                        pitch_class = int(parts[0][1:])
                        octave = int(parts[1][1:])
                        vel_level = parts[2]
                        timing = parts[3]
                        
                        # Constrain octave to reasonable range
                        octave = max(3, min(7, octave))
                        note = (octave * 12) + pitch_class
                        
                        # Ensure note is in valid MIDI range (0-127)
                        note = max(0, min(127, note))
                        
                        # Convert velocity level to MIDI velocity
                        velocity_map = {
                            "pp": 35, "mp": 55, "mf": 75, "f": 95, "ff": 115
                        }
                        velocity = velocity_map.get(vel_level, 70)
                        
                        # Convert timing to ticks - make them shorter for better playback
                        timing_map = {
                            "T1": 240,   # Eighth note
                            "T2": 480,   # Quarter note  
                            "T3": 720,   # Dotted quarter
                            "T4": 960,   # Half note
                            "T5": 1440   # Dotted half
                        }
                        duration = timing_map.get(timing, 480)
                        
                        # Add note on event
                        events.append(('note_on', current_time, note, velocity))
                        # Add note off event
                        events.append(('note_off', current_time + int(duration * 0.9), note, 0))
                        
                        # Advance time for next note (with some overlap allowed)
                        current_time += int(duration * 0.7)  # 70% spacing allows overlap
                        
                except (ValueError, IndexError):
                    current_time += 480  # Default quarter note spacing
            else:
                current_time += 240  # Shorter default for non-notes
        
        # Sort events by time
        events.sort(key=lambda x: x[1])
        
        # Convert to MIDI messages with delta times
        last_time = 0
        for event in events:
            event_type, abs_time, note, velocity = event
            delta_time = abs_time - last_time
            
            if event_type == 'note_on':
                track.append(mido.Message('note_on', channel=0, note=note, 
                                        velocity=velocity, time=delta_time))
            else:  # note_off
                track.append(mido.Message('note_off', channel=0, note=note, 
                                        velocity=64, time=delta_time))
            
            last_time = abs_time
        
        # Add a final rest
        track.append(mido.Message('note_off', channel=0, note=60, velocity=0, time=480))
        
        mid.save(output_path)
        print(f"Generated MIDI saved as: {output_path}")
        print(f"Total events: {len(events)}")
        print(f"Duration: ~{current_time / 480:.1f} beats")
    
    def save_model(self, filepath):
        """Save the trained model"""
        model_data = {
            'trigram_model': dict(self.trigram_model),
            'tempos': self.tempos,
            'time_signatures': self.time_signatures
        }
        with open(filepath, 'wb') as f:
            pickle.dump(model_data, f)
        print(f"Model saved to: {filepath}")
    
    def load_model(self, filepath):
        """Load a trained model"""
        with open(filepath, 'rb') as f:
            model_data = pickle.load(f)
        
        self.trigram_model = defaultdict(Counter, model_data['trigram_model'])
        self.tempos = model_data['tempos']
        self.time_signatures = model_data['time_signatures']
        print(f"Model loaded from: {filepath}")

# Test function to create a simple MIDI file for verification
def create_test_midi():
    """Create a simple test MIDI file to verify the MIDI writing works"""
    mid = MidiFile(ticks_per_beat=480)
    track = MidiTrack()
    mid.tracks.append(track)
    
    # Add tempo and time signature
    track.append(mido.MetaMessage('set_tempo', tempo=500000, time=0))
    track.append(mido.MetaMessage('time_signature', numerator=4, denominator=4, time=0))
    
    # Simple C major scale
    notes = [60, 62, 64, 65, 67, 69, 71, 72]  # C4 to C5
    for i, note in enumerate(notes):
        # Note on
        track.append(mido.Message('note_on', channel=0, note=note, velocity=80, time=0))
        # Note off after quarter note
        track.append(mido.Message('note_off', channel=0, note=note, velocity=0, time=480))
    
    mid.save("test_scale.mid")
    print("Test MIDI file created: test_scale.mid")

# %%
# Initialize the generator
generator = SymbolicMusicGenerator()

# Train on your dataset
dataset_path = "maestro-v3.0.0"
generator.train_on_dataset(dataset_path, max_files=300)  # Adjust max_files as needed

# Save the trained model
generator.save_model("music_model.pkl")

# Generate new music
print("\nGenerating new music...")
sequence = generator.generate_sequence(length=500)
generator.sequence_to_midi(sequence, "task1.mid")
print("Music generation completed!")
# Out:
# Scanning for MIDI files...
# Found 1276 MIDI files
# Processing 300 randomly selected files
# Processing: MIDI-Unprocessed_22_R2_2006_01_ORIG_MID--AUDIO_22_R2_2006_04_Track04_wav.midi (1/300)
# Processing: MIDI-Unprocessed_02_R1_2009_01-02_ORIG_MID--AUDIO_02_R1_2009_02_R1_2009_02_WAV.midi (2/300)
# Processing: MIDI-UNPROCESSED_06-08_R1_2014_MID--AUDIO_08_R1_2014_wav--2.midi (3/300)
# Processing: MIDI-Unprocessed_XP_04_R2_2004_01_ORIG_MID--AUDIO_04_R2_2004_01_Track01_wav.midi (4/300)
# Processing: MIDI-UNPROCESSED_16-18_R1_2014_MID--AUDIO_18_R1_2014_wav--4.midi (5/300)
# Processing: MIDI-Unprocessed_XP_21_R1_2004_02_ORIG_MID--AUDIO_21_R1_2004_02_Track02_wav.midi (6/300)
# Processing: MIDI-Unprocessed_23_R3_2011_MID--AUDIO_R3-D8_05_Track05_wav.midi (7/300)
# Processing: MIDI-Unprocessed_17_R2_2008_01-04_ORIG_MID--AUDIO_17_R2_2008_wav--2.midi (8/300)
# Processing: MIDI-Unprocessed_XP_08_R1_2004_01-02_ORIG_MID--AUDIO_08_R1_2004_01_Track01_wav.midi (9/300)
# Processing: MIDI-Unprocessed_08_R1_2011_MID--AUDIO_R1-D3_09_Track09_wav.midi (10/300)
# Processing: MIDI-Unprocessed_05_R1_2008_01-04_ORIG_MID--AUDIO_05_R1_2008_wav--2.midi (11/300)
# Processing: MIDI-Unprocessed_24_R1_2006_01-05_ORIG_MID--AUDIO_24_R1_2006_02_Track02_wav.midi (12/300)
# Processing: MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_20_R1_2015_wav--1.midi (13/300)
# Processing: ORIG-MIDI_02_7_7_13_Group__MID--AUDIO_15_R1_2013_wav--4.midi (14/300)
# Processing: MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_04_R1_2015_wav--3.midi (15/300)
# Processing: MIDI-Unprocessed_18_R1_2008_01-04_ORIG_MID--AUDIO_18_R1_2008_wav--4.midi (16/300)
# Processing: MIDI-UNPROCESSED_11-13_R1_2014_MID--AUDIO_11_R1_2014_wav--2.midi (17/300)
# Processing: ORIG-MIDI_02_7_7_13_Group__MID--AUDIO_17_R1_2013_wav--2.midi (18/300)
# Processing: MIDI-Unprocessed_06_R2_2008_01-05_ORIG_MID--AUDIO_06_R2_2008_wav--3.midi (19/300)
# Processing: ORIG-MIDI_03_7_6_13_Group__MID--AUDIO_09_R1_2013_wav--3.midi (20/300)
# Processing: MIDI-UNPROCESSED_04-08-12_R3_2014_MID--AUDIO_08_R3_2014_wav.midi (21/300)
# Processing: ORIG-MIDI_03_7_10_13_Group_MID--AUDIO_15_R3_2013_wav--2.midi (22/300)
# Processing: MIDI-UNPROCESSED_01-03_R1_2014_MID--AUDIO_01_R1_2014_wav--3.midi (23/300)
# Processing: MIDI-Unprocessed_06_R1_2009_03-07_ORIG_MID--AUDIO_06_R1_2009_06_R1_2009_06_WAV.midi (24/300)
# Processing: MIDI-Unprocessed_Recital5-7_MID--AUDIO_06_R1_2018_wav--2.midi (25/300)
# Processing: MIDI-Unprocessed_25_R3_2011_MID--AUDIO_R3-D9_03_Track03_wav.midi (26/300)
# Processing: MIDI-Unprocessed_Recital5-7_MID--AUDIO_06_R1_2018_wav--3.midi (27/300)
# Processing: MIDI-Unprocessed_21_R1_2009_01-03_ORIG_MID--AUDIO_21_R1_2009_21_R1_2009_03_WAV.midi (28/300)
# Processing: MIDI-Unprocessed_Recital20_MID--AUDIO_20_R1_2018_wav--4.midi (29/300)
# Processing: ORIG-MIDI_02_7_7_13_Group__MID--AUDIO_16_R1_2013_wav--2.midi (30/300)
# Processing: MIDI-Unprocessed_18_R1_2011_MID--AUDIO_R1-D7_10_Track10_wav.midi (31/300)
# Processing: MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_02_R1_2015_wav--6.midi (32/300)
# Processing: MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_13_R1_2015_wav--2.midi (33/300)
# Processing: MIDI-Unprocessed_04_R3_2008_01-07_ORIG_MID--AUDIO_04_R3_2008_wav--1.midi (34/300)
# Processing: MIDI-UNPROCESSED_06-08_R1_2014_MID--AUDIO_07_R1_2014_wav--4.midi (35/300)
# Processing: MIDI-Unprocessed_06_R1_2011_MID--AUDIO_R1-D2_16_Track16_wav.midi (36/300)
# Processing: MIDI-Unprocessed_070_PIANO070_MID--AUDIO-split_07-08-17_Piano-e_1-02_wav--1.midi (37/300)
# Processing: MIDI-Unprocessed_058_PIANO058_MID--AUDIO-split_07-07-17_Piano-e_2-02_wav--5.midi (38/300)
# Processing: ORIG-MIDI_02_7_7_13_Group__MID--AUDIO_19_R1_2013_wav--2.midi (39/300)
# Processing: MIDI-Unprocessed_23_R2_2006_01_ORIG_MID--AUDIO_23_R2_2006_04_Track04_wav.midi (40/300)
# Processing: MIDI-Unprocessed_09_R1_2006_01-04_ORIG_MID--AUDIO_09_R1_2006_01_Track01_wav.midi (41/300)
# Processing: MIDI-Unprocessed_08_R1_2009_01-04_ORIG_MID--AUDIO_08_R1_2009_08_R1_2009_01_WAV.midi (42/300)
# Processing: ORIG-MIDI_02_7_7_13_Group__MID--AUDIO_17_R1_2013_wav--3.midi (43/300)
# Processing: MIDI-Unprocessed_01_R1_2008_01-04_ORIG_MID--AUDIO_01_R1_2008_wav--2.midi (44/300)
# Processing: MIDI-UNPROCESSED_06-08_R1_2014_MID--AUDIO_07_R1_2014_wav--7.midi (45/300)
# Processing: MIDI-Unprocessed_054_PIANO054_MID--AUDIO-split_07-07-17_Piano-e_1-02_wav--3.midi (46/300)
# Processing: MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-from_mp3_12_R1_2015_wav--1.midi (47/300)
# Processing: MIDI-Unprocessed_045_PIANO045_MID--AUDIO-split_07-06-17_Piano-e_2-01_wav--1.midi (48/300)
# Processing: ORIG-MIDI_01_7_10_13_Group_MID--AUDIO_02_R3_2013_wav--1.midi (49/300)
# Processing: MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_03_R1_2015_wav--1.midi (50/300)
# Processing: MIDI-Unprocessed_08_R2_2006_01_ORIG_MID--AUDIO_08_R2_2006_02_Track02_wav.midi (51/300)
# Processing: MIDI-Unprocessed_SMF_07_R1_2004_01_ORIG_MID--AUDIO_07_R1_2004_12_Track12_wav.midi (52/300)
# Processing: MIDI-Unprocessed_12_R1_2011_MID--AUDIO_R1-D4_13_Track13_wav.midi (53/300)
# Processing: MIDI-Unprocessed_Chamber2_MID--AUDIO_09_R3_2018_wav--1.midi (54/300)
# Processing: MIDI-Unprocessed_07_R1_2006_01-04_ORIG_MID--AUDIO_07_R1_2006_04_Track04_wav.midi (55/300)
# Processing: MIDI-Unprocessed_12_R1_2011_MID--AUDIO_R1-D4_14_Track14_wav.midi (56/300)
# Processing: MIDI-Unprocessed_22_R3_2011_MID--AUDIO_R3-D7_03_Track03_wav.midi (57/300)
# Processing: MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_07_R1_2015_wav--1.midi (58/300)
# Processing: MIDI-Unprocessed_XP_11_R1_2004_01-02_ORIG_MID--AUDIO_11_R1_2004_02_Track02_wav.midi (59/300)
# Processing: MIDI-Unprocessed_09_R1_2008_01-05_ORIG_MID--AUDIO_09_R1_2008_wav--5.midi (60/300)
# Processing: MIDI-Unprocessed_25_R1_2011_MID--AUDIO_R1-D9_14_Track14_wav.midi (61/300)
# Processing: MIDI-Unprocessed_073_PIANO073_MID--AUDIO-split_07-08-17_Piano-e_2-02_wav--1.midi (62/300)
# Processing: MIDI-Unprocessed_11_R2_2008_01-05_ORIG_MID--AUDIO_11_R2_2008_wav--5.midi (63/300)
# Processing: MIDI-Unprocessed_16_R1_2011_MID--AUDIO_R1-D6_15_Track15_wav.midi (64/300)
# Processing: MIDI-Unprocessed_11_R1_2011_MID--AUDIO_R1-D4_07_Track07_wav.midi (65/300)
# Processing: MIDI-Unprocessed_15_R1_2008_01-04_ORIG_MID--AUDIO_15_R1_2008_wav--4.midi (66/300)
# Processing: MIDI-Unprocessed_01_R1_2011_MID--AUDIO_R1-D1_03_Track03_wav.midi (67/300)
# Processing: MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_13_R1_2015_wav--1.midi (68/300)
# Processing: ORIG-MIDI_01_7_8_13_Group__MID--AUDIO_07_R2_2013_wav--2.midi (69/300)
# Processing: MIDI-Unprocessed_XP_16_R2_2004_01_ORIG_MID--AUDIO_16_R2_2004_01_Track01_wav.midi (70/300)
# Processing: MIDI-Unprocessed_17_R1_2006_01-06_ORIG_MID--AUDIO_17_R1_2006_02_Track02_wav.midi (71/300)
# Processing: MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_15_R2_2014_wav.midi (72/300)
# Processing: ORIG-MIDI_01_7_7_13_Group__MID--AUDIO_13_R1_2013_wav--1.midi (73/300)
# Processing: MIDI-Unprocessed_16_R1_2008_01-04_ORIG_MID--AUDIO_16_R1_2008_wav--2.midi (74/300)
# Processing: MIDI-Unprocessed_04_R2_2011_MID--AUDIO_R2-D2_02_Track02_wav.midi (75/300)
# Processing: MIDI-Unprocessed_XP_14_R1_2004_01-03_ORIG_MID--AUDIO_14_R1_2004_03_Track03_wav.midi (76/300)
# Processing: MIDI-Unprocessed_02_R2_2008_01-05_ORIG_MID--AUDIO_02_R2_2008_wav--3.midi (77/300)
# Processing: MIDI-UNPROCESSED_11-13_R1_2014_MID--AUDIO_11_R1_2014_wav--1.midi (78/300)
# Processing: MIDI-Unprocessed_16_R1_2009_03-06_ORIG_MID--AUDIO_16_R1_2009_16_R1_2009_03_WAV.midi (79/300)
# Processing: MIDI-UNPROCESSED_19-20-21_R2_2014_MID--AUDIO_19_R2_2014_wav.midi (80/300)
# Processing: MIDI-Unprocessed_XP_04_R1_2004_03-05_ORIG_MID--AUDIO_04_R1_2004_04_Track04_wav.midi (81/300)
# Processing: MIDI-Unprocessed_12_R2_2011_MID--AUDIO_R2-D4_03_Track03_wav.midi (82/300)
# Processing: MIDI-Unprocessed_19_R1_2009_01-02_ORIG_MID--AUDIO_19_R1_2009_19_R1_2009_02_WAV.midi (83/300)
# Processing: MIDI-Unprocessed_SMF_16_R1_2004_01-08_ORIG_MID--AUDIO_16_R1_2004_06_Track06_wav.midi (84/300)
# Processing: MIDI-Unprocessed_082_PIANO082_MID--AUDIO-split_07-09-17_Piano-e_2_-04_wav--3.midi (85/300)
# Processing: MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_10_Track10_wav.midi (86/300)
# Processing: MIDI-Unprocessed_XP_21_R1_2004_01_ORIG_MID--AUDIO_21_R1_2004_01_Track01_wav.midi (87/300)
# Processing: MIDI-Unprocessed_053_PIANO053_MID--AUDIO-split_07-06-17_Piano-e_3-04_wav--4.midi (88/300)
# Processing: MIDI-Unprocessed_Chamber6_MID--AUDIO_20_R3_2018_wav--1.midi (89/300)
# Processing: MIDI-UNPROCESSED_11-13_R1_2014_MID--AUDIO_13_R1_2014_wav--6.midi (90/300)
# Processing: MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_18_R1_2015_wav--4.midi (91/300)
# Processing: MIDI-Unprocessed_Recital9-11_MID--AUDIO_10_R1_2018_wav--3.midi (92/300)
# Processing: MIDI-Unprocessed_19_R1_2011_MID--AUDIO_R1-D7_13_Track13_wav.midi (93/300)
# Processing: MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-from_mp3_12_R1_2015_wav--4.midi (94/300)
# Processing: MIDI-Unprocessed_03_R1_2011_MID--AUDIO_R1-D1_17_Track17_wav.midi (95/300)
# Processing: MIDI-Unprocessed_06_R1_2008_01-04_ORIG_MID--AUDIO_06_R1_2008_wav--3.midi (96/300)
# Processing: MIDI-Unprocessed_XP_14_R1_2004_04_ORIG_MID--AUDIO_14_R1_2004_06_Track06_wav.midi (97/300)
# Processing: MIDI-Unprocessed_17_R2_2009_01_ORIG_MID--AUDIO_17_R2_2009_17_R2_2009_01_WAV.midi (98/300)
# Processing: MIDI-Unprocessed_053_PIANO053_MID--AUDIO-split_07-06-17_Piano-e_3-04_wav--3.midi (99/300)
# Processing: MIDI-Unprocessed_Recital9-11_MID--AUDIO_10_R1_2018_wav--5.midi (100/300)
# Processing: MIDI-Unprocessed_071_PIANO071_MID--AUDIO-split_07-08-17_Piano-e_1-04_wav--2.midi (101/300)
# Processing: MIDI-UNPROCESSED_16-18_R1_2014_MID--AUDIO_18_R1_2014_wav--5.midi (102/300)
# Processing: MIDI-Unprocessed_SMF_17_R1_2004_01-02_ORIG_MID--AUDIO_20_R2_2004_06_Track06_wav.midi (103/300)
# Processing: ORIG-MIDI_03_7_10_13_Group_MID--AUDIO_17_R3_2013_wav--3.midi (104/300)
# Processing: ORIG-MIDI_03_7_8_13_Group__MID--AUDIO_15_R2_2013_wav--2.midi (105/300)
# Processing: MIDI-Unprocessed_XP_09_R1_2004_05_ORIG_MID--AUDIO_09_R1_2004_08_Track08_wav.midi (106/300)
# Processing: MIDI-Unprocessed_Recital1-3_MID--AUDIO_03_R1_2018_wav--4.midi (107/300)
# Processing: MIDI-Unprocessed_02_R1_2006_01-04_ORIG_MID--AUDIO_02_R1_2006_02_Track02_wav.midi (108/300)
# Processing: MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-from_mp3_10_R1_2015_wav--3.midi (109/300)
# Processing: MIDI-Unprocessed_18_R1_2006_01-05_ORIG_MID--AUDIO_18_R1_2006_04_Track04_wav.midi (110/300)
# Processing: MIDI-Unprocessed_18_R1_2011_MID--AUDIO_R1-D7_07_Track07_wav.midi (111/300)
# Processing: MIDI-Unprocessed_Recital13-15_MID--AUDIO_14_R1_2018_wav--3.midi (112/300)
# Processing: ORIG-MIDI_02_7_8_13_Group__MID--AUDIO_14_R2_2013_wav--1.midi (113/300)
# Processing: MIDI-Unprocessed_R2_D1-2-3-6-7-8-11_mid--AUDIO-from_mp3_07_R2_2015_wav--1.midi (114/300)
# Processing: MIDI-Unprocessed_15_R2_2008_01-04_ORIG_MID--AUDIO_15_R2_2008_wav--3.midi (115/300)
# Processing: MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_02_R1_2015_wav--4.midi (116/300)
# Processing: MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-from_mp3_12_R1_2015_wav--2.midi (117/300)
# Processing: MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_19_R1_2015_wav--1.midi (118/300)
# Processing: MIDI-Unprocessed_09_R2_2006_01_ORIG_MID--AUDIO_09_R2_2006_03_Track03_wav.midi (119/300)
# Processing: MIDI-Unprocessed_Recital5-7_MID--AUDIO_07_R1_2018_wav--3.midi (120/300)
# Processing: ORIG-MIDI_02_7_8_13_Group__MID--AUDIO_12_R2_2013_wav--1.midi (121/300)
# Processing: ORIG-MIDI_02_7_6_13_Group__MID--AUDIO_08_R1_2013_wav--5.midi (122/300)
# Processing: MIDI-Unprocessed_08_R1_2009_01-04_ORIG_MID--AUDIO_08_R1_2009_08_R1_2009_03_WAV.midi (123/300)
# Processing: MIDI-UNPROCESSED_06-08_R1_2014_MID--AUDIO_07_R1_2014_wav--6.midi (124/300)
# Processing: MIDI-Unprocessed_11_R2_2008_01-05_ORIG_MID--AUDIO_11_R2_2008_wav--3.midi (125/300)
# Processing: MIDI-Unprocessed_10_R2_2008_01-05_ORIG_MID--AUDIO_10_R2_2008_wav--4.midi (126/300)
# Processing: MIDI-UNPROCESSED_19-21_R3_2014_MID--AUDIO_21_R3_2014_wav--1.midi (127/300)
# Processing: MIDI-Unprocessed_XP_15_R2_2004_01_ORIG_MID--AUDIO_15_R2_2004_03_Track03_wav.midi (128/300)
# Processing: MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-from_mp3_09_R1_2015_wav--2.midi (129/300)
# Processing: MIDI-Unprocessed_SMF_12_01_2004_01-05_ORIG_MID--AUDIO_12_R1_2004_10_Track10_wav.midi (130/300)
# Processing: MIDI-Unprocessed_Recital1-3_MID--AUDIO_01_R1_2018_wav--2.midi (131/300)
# Processing: MIDI-Unprocessed_08_R1_2009_01-04_ORIG_MID--AUDIO_08_R1_2009_08_R1_2009_04_WAV.midi (132/300)
# Processing: MIDI-Unprocessed_12_R1_2008_01-04_ORIG_MID--AUDIO_12_R1_2008_wav--4.midi (133/300)
# Processing: MIDI-Unprocessed_044_PIANO044_MID--AUDIO-split_07-06-17_Piano-e_1-04_wav--2.midi (134/300)
# Processing: MIDI-Unprocessed_22_R3_2011_MID--AUDIO_R3-D7_07_Track07_wav.midi (135/300)
# Processing: MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_13_R1_2015_wav--5.midi (136/300)
# Processing: MIDI-Unprocessed_Recital13-15_MID--AUDIO_13_R1_2018_wav--3.midi (137/300)
# Processing: MIDI-UNPROCESSED_06-08_R1_2014_MID--AUDIO_08_R1_2014_wav--1.midi (138/300)
# Processing: MIDI-Unprocessed_XP_19_R1_2004_01-02_ORIG_MID--AUDIO_19_R1_2004_01_Track01_wav.midi (139/300)
# Processing: ORIG-MIDI_02_7_7_13_Group__MID--AUDIO_17_R1_2013_wav--4.midi (140/300)
# Processing: MIDI-Unprocessed_SMF_13_01_2004_01-05_ORIG_MID--AUDIO_13_R1_2004_09_Track09_wav.midi (141/300)
# Processing: MIDI-UNPROCESSED_19-20_R1_2014_MID--AUDIO_20_R1_2014_wav--1.midi (142/300)
# Processing: MIDI-Unprocessed_07_R1_2008_01-04_ORIG_MID--AUDIO_07_R1_2008_wav--4.midi (143/300)
# Processing: MIDI-Unprocessed_057_PIANO057_MID--AUDIO-split_07-07-17_Piano-e_1-07_wav--4.midi (144/300)
# Processing: MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_03_R1_2015_wav--2.midi (145/300)
# Processing: MIDI-Unprocessed_XP_06_R2_2004_01_ORIG_MID--AUDIO_06_R2_2004_01_Track01_wav.midi (146/300)
# Processing: MIDI-Unprocessed_05_R1_2009_01-02_ORIG_MID--AUDIO_05_R1_2009_05_R1_2009_01_WAV.midi (147/300)
# Processing: MIDI-Unprocessed_072_PIANO072_MID--AUDIO-split_07-08-17_Piano-e_1-06_wav--4.midi (148/300)
# Processing: ORIG-MIDI_02_7_10_13_Group_MID--AUDIO_11_R3_2013_wav--3.midi (149/300)
# Processing: MIDI-Unprocessed_SMF_22_R1_2004_01-04_ORIG_MID--AUDIO_22_R1_2004_05_Track05_wav.midi (150/300)
# Processing: MIDI-Unprocessed_11_R1_2011_MID--AUDIO_R1-D4_10_Track10_wav.midi (151/300)
# Processing: MIDI-UNPROCESSED_16-18_R1_2014_MID--AUDIO_18_R1_2014_wav--3.midi (152/300)
# Processing: MIDI-Unprocessed_060_PIANO060_MID--AUDIO-split_07-07-17_Piano-e_2-04_wav--3.midi (153/300)
# Processing: MIDI-Unprocessed_12_R1_2009_01-02_ORIG_MID--AUDIO_12_R1_2009_12_R1_2009_01_WAV.midi (154/300)
# Processing: MIDI-Unprocessed_15_R2_2008_01-04_ORIG_MID--AUDIO_15_R2_2008_wav--2.midi (155/300)
# Processing: MIDI-Unprocessed_R2_D2-19-21-22_mid--AUDIO-from_mp3_19_R2_2015_wav--3.midi (156/300)
# Processing: MIDI-Unprocessed_19_R1_2006_01-07_ORIG_MID--AUDIO_19_R1_2006_01_Track01_wav.midi (157/300)
# Processing: MIDI-Unprocessed_12_R3_2008_01-04_ORIG_MID--AUDIO_12_R3_2008_wav--3.midi (158/300)
# Processing: MIDI-Unprocessed_12_R1_2006_01-08_ORIG_MID--AUDIO_12_R1_2006_04_Track04_wav.midi (159/300)
# Processing: MIDI-Unprocessed_14_R1_2008_01-05_ORIG_MID--AUDIO_14_R1_2008_wav--3.midi (160/300)
# Processing: MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_15_R1_2015_wav--3.midi (161/300)
# Processing: MIDI-UNPROCESSED_11-13_R1_2014_MID--AUDIO_13_R1_2014_wav--4.midi (162/300)
# Processing: MIDI-Unprocessed_SMF_17_R1_2004_01-02_ORIG_MID--AUDIO_20_R2_2004_02_Track02_wav.midi (163/300)
# Processing: MIDI-Unprocessed_047_PIANO047_MID--AUDIO-split_07-06-17_Piano-e_2-04_wav--1.midi (164/300)
# Processing: MIDI-Unprocessed_24_R1_2011_MID--AUDIO_R1-D9_09_Track09_wav.midi (165/300)
# Processing: MIDI-Unprocessed_SMF_17_R1_2004_04_ORIG_MID--AUDIO_17_R1_2004_11_Track11_wav.midi (166/300)
# Processing: MIDI-Unprocessed_082_PIANO082_MID--AUDIO-split_07-09-17_Piano-e_2_-04_wav--2.midi (167/300)
# Processing: MIDI-Unprocessed_12_R1_2008_01-04_ORIG_MID--AUDIO_12_R1_2008_wav--1.midi (168/300)
# Processing: ORIG-MIDI_01_7_6_13_Group__MID--AUDIO_02_R1_2013_wav--1.midi (169/300)
# Processing: MIDI-Unprocessed_15_R2_2008_01-04_ORIG_MID--AUDIO_15_R2_2008_wav--4.midi (170/300)
# Processing: MIDI-Unprocessed_XP_22_R2_2004_01_ORIG_MID--AUDIO_22_R2_2004_02_Track02_wav.midi (171/300)
# Processing: MIDI-Unprocessed_XP_11_R1_2004_03-04_ORIG_MID--AUDIO_11_R1_2004_03_Track03_wav.midi (172/300)
# Processing: MIDI-Unprocessed_058_PIANO058_MID--AUDIO-split_07-07-17_Piano-e_2-02_wav--4.midi (173/300)
# Processing: MIDI-Unprocessed_04_R3_2011_MID--AUDIO_R3-D2_03_Track03_wav.midi (174/300)
# Processing: MIDI-Unprocessed_09_R1_2008_01-05_ORIG_MID--AUDIO_09_R1_2008_wav--4.midi (175/300)
# Processing: MIDI-Unprocessed_Schubert4-6_MID--AUDIO_09_R2_2018_wav.midi (176/300)
# Processing: MIDI-Unprocessed_060_PIANO060_MID--AUDIO-split_07-07-17_Piano-e_2-04_wav--1.midi (177/300)
# Processing: MIDI-Unprocessed_Recital13-15_MID--AUDIO_13_R1_2018_wav--2.midi (178/300)
# Processing: ORIG-MIDI_02_7_8_13_Group__MID--AUDIO_11_R2_2013_wav--1.midi (179/300)
# Processing: MIDI-Unprocessed_083_PIANO083_MID--AUDIO-split_07-09-17_Piano-e_2_-06_wav--2.midi (180/300)
# Processing: MIDI-Unprocessed_02_R1_2008_01-05_ORIG_MID--AUDIO_02_R1_2008_wav--3.midi (181/300)
# Processing: MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-from_mp3_10_R1_2015_wav--1.midi (182/300)
# Processing: MIDI-Unprocessed_13_R1_2006_01-06_ORIG_MID--AUDIO_13_R1_2006_04_Track04_wav.midi (183/300)
# Processing: MIDI-Unprocessed_074_PIANO074_MID--AUDIO-split_07-08-17_Piano-e_2-04_wav--2.midi (184/300)
# Processing: MIDI-UNPROCESSED_04-07-08-10-12-15-17_R2_2014_MID--AUDIO_12_R2_2014_wav.midi (185/300)
# Processing: ORIG-MIDI_02_7_10_13_Group_MID--AUDIO_14_R3_2013_wav--1.midi (186/300)
# Processing: MIDI-Unprocessed_15_R1_2011_MID--AUDIO_R1-D6_08_Track08_wav.midi (187/300)
# Processing: MIDI-Unprocessed_22_R1_2011_MID--AUDIO_R1-D8_12_Track12_wav.midi (188/300)
# Processing: MIDI-Unprocessed_R2_D1-2-3-6-7-8-11_mid--AUDIO-from_mp3_08_R2_2015_wav--3.midi (189/300)
# Processing: MIDI-Unprocessed_R2_D2-19-21-22_mid--AUDIO-from_mp3_21_R2_2015_wav--1.midi (190/300)
# Processing: MIDI-Unprocessed_078_PIANO078_MID--AUDIO-split_07-09-17_Piano-e_1-02_wav--2.midi (191/300)
# Processing: MIDI-Unprocessed_05_R1_2011_MID--AUDIO_R1-D2_08_Track08_wav.midi (192/300)
# Processing: MIDI-Unprocessed_07_R3_2008_01-05_ORIG_MID--AUDIO_07_R3_2008_wav--4.midi (193/300)
# Processing: MIDI-Unprocessed_071_PIANO071_MID--AUDIO-split_07-08-17_Piano-e_1-04_wav--1.midi (194/300)
# Processing: MIDI-Unprocessed_042_PIANO042_MID--AUDIO-split_07-06-17_Piano-e_1-02_wav--2.midi (195/300)
# Processing: MIDI-Unprocessed_17_R3_2011_MID--AUDIO_R3-D6_05_Track05_wav.midi (196/300)
# Processing: MIDI-Unprocessed_11_R1_2008_01-04_ORIG_MID--AUDIO_11_R1_2008_wav--2.midi (197/300)
# Processing: MIDI-Unprocessed_041_PIANO041_MID--AUDIO-split_07-06-17_Piano-e_1-01_wav--3.midi (198/300)
# Processing: MIDI-Unprocessed_23_R1_2011_MID--AUDIO_R1-D9_03_Track03_wav.midi (199/300)
# Processing: MIDI-Unprocessed_SMF_13_01_2004_01-05_ORIG_MID--AUDIO_13_R1_2004_05_Track05_wav.midi (200/300)
# Processing: MIDI-Unprocessed_05_R1_2011_MID--AUDIO_R1-D2_10_Track10_wav.midi (201/300)
# Processing: MIDI-Unprocessed_24_R1_2011_MID--AUDIO_R1-D9_11_Track11_wav.midi (202/300)
# Processing: MIDI-Unprocessed_03_R3_2011_MID--AUDIO_R3-D1_05_Track05_wav.midi (203/300)
# Processing: ORIG-MIDI_02_7_7_13_Group__MID--AUDIO_19_R1_2013_wav--3.midi (204/300)
# Processing: MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_07_R1_2015_wav--4.midi (205/300)
# Processing: MIDI-Unprocessed_SMF_07_R1_2004_01_ORIG_MID--AUDIO_07_R1_2004_06_Track06_wav.midi (206/300)
# Processing: MIDI-Unprocessed_15_R1_2008_01-04_ORIG_MID--AUDIO_15_R1_2008_wav--1.midi (207/300)
# Processing: ORIG-MIDI_01_7_7_13_Group__MID--AUDIO_11_R1_2013_wav--4.midi (208/300)
# Processing: MIDI-Unprocessed_04_R1_2006_01-04_ORIG_MID--AUDIO_04_R1_2006_02_Track02_wav.midi (209/300)
# Processing: MIDI-UNPROCESSED_09-10_R1_2014_MID--AUDIO_09_R1_2014_wav--2.midi (210/300)
# Processing: MIDI-Unprocessed_17_R2_2008_01-04_ORIG_MID--AUDIO_17_R2_2008_wav--3.midi (211/300)
# Processing: MIDI-Unprocessed_081_PIANO081_MID--AUDIO-split_07-09-17_Piano-e_2_-02_wav--4.midi (212/300)
# Processing: MIDI-Unprocessed_081_PIANO081_MID--AUDIO-split_07-09-17_Piano-e_2_-02_wav--3.midi (213/300)
# Processing: MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_05_Track05_wav.midi (214/300)
# Processing: MIDI-Unprocessed_23_R2_2011_MID--AUDIO_R2-D6_04_Track04_wav.midi (215/300)
# Processing: MIDI-Unprocessed_R1_D2-21-22_mid--AUDIO-from_mp3_22_R1_2015_wav--1.midi (216/300)
# Processing: MIDI-Unprocessed_XP_08_R1_2004_04-06_ORIG_MID--AUDIO_08_R1_2004_04_Track04_wav.midi (217/300)
# Processing: MIDI-Unprocessed_066_PIANO066_MID--AUDIO-split_07-07-17_Piano-e_3-02_wav--2.midi (218/300)
# Processing: MIDI-Unprocessed_Recital8_MID--AUDIO_08_R1_2018_wav--4.midi (219/300)
# Processing: MIDI-Unprocessed_XP_19_R2_2004_01_ORIG_MID--AUDIO_19_R2_2004_01_Track01_wav.midi (220/300)
# Processing: MIDI-Unprocessed_07_R2_2006_01_ORIG_MID--AUDIO_07_R2_2006_02_Track02_wav.midi (221/300)
# Processing: MIDI-Unprocessed_17_R1_2011_MID--AUDIO_R1-D7_05_Track05_wav.midi (222/300)
# Processing: MIDI-Unprocessed_09_R3_2008_01-07_ORIG_MID--AUDIO_09_R3_2008_wav--5.midi (223/300)
# Processing: MIDI-Unprocessed_19_R1_2009_03-04_ORIG_MID--AUDIO_19_R1_2009_19_R1_2009_04_WAV.midi (224/300)
# Processing: MIDI-Unprocessed_12_R1_2006_01-08_ORIG_MID--AUDIO_12_R1_2006_06_Track06_wav.midi (225/300)
# Processing: MIDI-Unprocessed_04_R3_2008_01-07_ORIG_MID--AUDIO_04_R3_2008_wav--3.midi (226/300)
# Processing: MIDI-Unprocessed_17_R3_2011_MID--AUDIO_R3-D6_03_Track03_wav.midi (227/300)
# Processing: MIDI-Unprocessed_01_R1_2009_01-04_ORIG_MID--AUDIO_01_R1_2009_01_R1_2009_02_WAV.midi (228/300)
# Processing: MIDI-Unprocessed_14_R1_2009_06-08_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_06_WAV.midi (229/300)
# Processing: MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_05_R1_2015_wav--1.midi (230/300)
# Processing: MIDI-Unprocessed_08_R1_2008_01-05_ORIG_MID--AUDIO_08_R1_2008_wav--4.midi (231/300)
# Processing: MIDI-Unprocessed_042_PIANO042_MID--AUDIO-split_07-06-17_Piano-e_1-02_wav--3.midi (232/300)
# Processing: MIDI-Unprocessed_XP_17_R2_2004_01_ORIG_MID--AUDIO_17_R2_2004_03_Track03_wav.midi (233/300)
# Processing: MIDI-Unprocessed_03_R1_2006_01-05_ORIG_MID--AUDIO_03_R1_2006_04_Track04_wav.midi (234/300)
# Processing: MIDI-Unprocessed_02_R1_2006_01-04_ORIG_MID--AUDIO_02_R1_2006_01_Track01_wav.midi (235/300)
# Processing: MIDI-Unprocessed_05_R1_2009_03-05_ORIG_MID--AUDIO_05_R1_2009_05_R1_2009_03_WAV.midi (236/300)
# Processing: MIDI-Unprocessed_Schubert1-3_MID--AUDIO_02_R2_2018_wav.midi (237/300)
# Processing: MIDI-Unprocessed_14_R1_2009_01-05_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_03_WAV.midi (238/300)
# Processing: MIDI-Unprocessed_058_PIANO058_MID--AUDIO-split_07-07-17_Piano-e_2-02_wav--1.midi (239/300)
# Processing: MIDI-Unprocessed_080_PIANO080_MID--AUDIO-split_07-09-17_Piano-e_1-06_wav--1.midi (240/300)
# Processing: MIDI-Unprocessed_12_R3_2011_MID--AUDIO_R3-D4_09_Track09_wav.midi (241/300)
# Processing: MIDI-Unprocessed_059_PIANO059_MID--AUDIO-split_07-07-17_Piano-e_2-03_wav--3.midi (242/300)
# Processing: MIDI-Unprocessed_055_PIANO055_MID--AUDIO-split_07-07-17_Piano-e_1-04_wav--2.midi (243/300)
# Processing: MIDI-Unprocessed_15_R1_2009_01-02_ORIG_MID--AUDIO_15_R1_2009_15_R1_2009_01_WAV.midi (244/300)
# Processing: ORIG-MIDI_02_7_6_13_Group__MID--AUDIO_06_R1_2013_wav--1.midi (245/300)
# Processing: MIDI-Unprocessed_02_R1_2009_03-06_ORIG_MID--AUDIO_02_R1_2009_02_R1_2009_03_WAV.midi (246/300)
# Processing: MIDI-Unprocessed_19_R1_2006_01-07_ORIG_MID--AUDIO_19_R1_2006_03_Track03_wav.midi (247/300)
# Processing: MIDI-Unprocessed_09_R2_2008_01-05_ORIG_MID--AUDIO_09_R2_2008_wav--5.midi (248/300)
# Processing: MIDI-Unprocessed_047_PIANO047_MID--AUDIO-split_07-06-17_Piano-e_2-04_wav--4.midi (249/300)
# Processing: ORIG-MIDI_01_7_7_13_Group__MID--AUDIO_12_R1_2013_wav--5.midi (250/300)
# Processing: MIDI-Unprocessed_Recital13-15_MID--AUDIO_15_R1_2018_wav--1.midi (251/300)
# Processing: MIDI-Unprocessed_02_R1_2011_MID--AUDIO_R1-D1_08_Track08_wav.midi (252/300)
# Processing: MIDI-Unprocessed_12_R3_2008_01-04_ORIG_MID--AUDIO_12_R3_2008_wav--1.midi (253/300)
# Processing: ORIG-MIDI_01_7_6_13_Group__MID--AUDIO_02_R1_2013_wav--5.midi (254/300)
# Processing: MIDI-Unprocessed_01_R2_2006_01_ORIG_MID--AUDIO_01_R2_2006_01_Track01_wav.midi (255/300)
# Processing: MIDI-Unprocessed_083_PIANO083_MID--AUDIO-split_07-09-17_Piano-e_2_-06_wav--1.midi (256/300)
# Processing: MIDI-Unprocessed_15_R1_2006_01-05_ORIG_MID--AUDIO_15_R1_2006_04_Track04_wav.midi (257/300)
# Processing: MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_05_R1_2015_wav--5.midi (258/300)
# Processing: MIDI-Unprocessed_19_R2_2009_01_ORIG_MID--AUDIO_19_R2_2009_19_R2_2009_02_WAV.midi (259/300)
# Processing: MIDI-Unprocessed_043_PIANO043_MID--AUDIO-split_07-06-17_Piano-e_1-03_wav--2.midi (260/300)
# Processing: MIDI-Unprocessed_25_R1_2011_MID--AUDIO_R1-D9_15_Track15_wav.midi (261/300)
# Processing: MIDI-Unprocessed_05_R1_2011_MID--AUDIO_R1-D2_09_Track09_wav.midi (262/300)
# Processing: MIDI-Unprocessed_Schubert10-12_MID--AUDIO_20_R2_2018_wav.midi (263/300)
# Processing: MIDI-UNPROCESSED_09-10_R1_2014_MID--AUDIO_10_R1_2014_wav--3.midi (264/300)
# Processing: MIDI-Unprocessed_R2_D2-12-13-15_mid--AUDIO-from_mp3_12_R2_2015_wav--2.midi (265/300)
# Processing: MIDI-Unprocessed_11_R1_2009_06-09_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_06_WAV.midi (266/300)
# Processing: MIDI-Unprocessed_XP_10_R1_2004_01-02_ORIG_MID--AUDIO_10_R1_2004_02_Track02_wav.midi (267/300)
# Processing: MIDI-Unprocessed_SMF_16_R1_2004_01-08_ORIG_MID--AUDIO_16_R1_2004_08_Track08_wav.midi (268/300)
# Processing: MIDI-Unprocessed_09_R3_2008_01-07_ORIG_MID--AUDIO_09_R3_2008_wav--4.midi (269/300)
# Processing: MIDI-Unprocessed_23_R3_2011_MID--AUDIO_R3-D8_04_Track04_wav.midi (270/300)
# Processing: MIDI-Unprocessed_09_R1_2011_MID--AUDIO_R1-D3_14_Track14_wav.midi (271/300)
# Processing: MIDI-UNPROCESSED_09-10_R1_2014_MID--AUDIO_09_R1_2014_wav--4.midi (272/300)
# Processing: MIDI-Unprocessed_XP_01_R1_2004_01-02_ORIG_MID--AUDIO_01_R1_2004_02_Track02_wav.midi (273/300)
# Processing: MIDI-Unprocessed_Schubert7-9_MID--AUDIO_11_R2_2018_wav.midi (274/300)
# Processing: MIDI-Unprocessed_XP_09_R1_2004_01-02_ORIG_MID--AUDIO_09_R1_2004_03_Track03_wav.midi (275/300)
# Processing: MIDI-Unprocessed_04_R2_2008_01-04_ORIG_MID--AUDIO_04_R2_2008_wav--3.midi (276/300)
# Processing: MIDI-Unprocessed_R2_D2-19-21-22_mid--AUDIO-from_mp3_21_R2_2015_wav--3.midi (277/300)
# Processing: MIDI-Unprocessed_060_PIANO060_MID--AUDIO-split_07-07-17_Piano-e_2-04_wav--5.midi (278/300)
# Processing: MIDI-Unprocessed_17_R3_2011_MID--AUDIO_R3-D6_08_Track08_wav.midi (279/300)
# Processing: ORIG-MIDI_03_7_10_13_Group_MID--AUDIO_17_R3_2013_wav--1.midi (280/300)
# Processing: MIDI-Unprocessed_17_R1_2006_01-06_ORIG_MID--AUDIO_17_R1_2006_01_Track01_wav.midi (281/300)
# Processing: ORIG-MIDI_01_7_6_13_Group__MID--AUDIO_04_R1_2013_wav--2.midi (282/300)
# Processing: ORIG-MIDI_03_7_10_13_Group_MID--AUDIO_17_R3_2013_wav--2.midi (283/300)
# Processing: MIDI-Unprocessed_Schubert10-12_MID--AUDIO_18_R2_2018_wav.midi (284/300)
# Processing: MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-from_mp3_12_R1_2015_wav--3.midi (285/300)
# Processing: MIDI-Unprocessed_12_R1_2006_01-08_ORIG_MID--AUDIO_12_R1_2006_03_Track03_wav.midi (286/300)
# Processing: ORIG-MIDI_01_7_10_13_Group_MID--AUDIO_08_R3_2013_wav--2.midi (287/300)
# Processing: MIDI-Unprocessed_11_R1_2011_MID--AUDIO_R1-D4_11_Track11_wav.midi (288/300)
# Processing: MIDI-Unprocessed_059_PIANO059_MID--AUDIO-split_07-07-17_Piano-e_2-03_wav--2.midi (289/300)
# Processing: MIDI-Unprocessed_Recital13-15_MID--AUDIO_14_R1_2018_wav--4.midi (290/300)
# Processing: MIDI-Unprocessed_08_R2_2009_01_ORIG_MID--AUDIO_08_R2_2009_08_R2_2009_04_WAV.midi (291/300)
# Processing: MIDI-UNPROCESSED_19-20_R1_2014_MID--AUDIO_19_R1_2014_wav--1.midi (292/300)
# Processing: MIDI-Unprocessed_R2_D2-19-21-22_mid--AUDIO-from_mp3_22_R2_2015_wav--1.midi (293/300)
# Processing: MIDI-Unprocessed_Recital5-7_MID--AUDIO_07_R1_2018_wav--4.midi (294/300)
# Processing: MIDI-Unprocessed_SMF_07_R1_2004_01_ORIG_MID--AUDIO_07_R1_2004_04_Track04_wav.midi (295/300)
# Processing: ORIG-MIDI_02_7_8_13_Group__MID--AUDIO_12_R2_2013_wav--2.midi (296/300)
# Processing: MIDI-Unprocessed_044_PIANO044_MID--AUDIO-split_07-06-17_Piano-e_1-04_wav--3.midi (297/300)
# Processing: MIDI-Unprocessed_056_PIANO056_MID--AUDIO-split_07-07-17_Piano-e_1-05_wav--1.midi (298/300)
# Processing: MIDI-Unprocessed_Recital9-11_MID--AUDIO_11_R1_2018_wav--1.midi (299/300)
# Processing: MIDI-Unprocessed_10_R2_2011_MID--AUDIO_R2-D3_10_Track10_wav.midi (300/300)
# Training completed on 300 files
# Learned 212933 trigram patterns
# Total notes processed: 1660533
# Octave distribution in training data:
#   Octave 1: 423 notes (0.0%)
#   Octave 2: 36925 notes (2.2%)
#   Octave 3: 164121 notes (9.9%)
#   Octave 4: 396623 notes (23.9%)
#   Octave 5: 542447 notes (32.7%)
#   Octave 6: 388991 notes (23.4%)
#   Octave 7: 116995 notes (7.0%)
#   Octave 8: 14006 notes (0.8%)
#   Octave 9: 2 notes (0.0%)
# Model saved to: music_model.pkl
#
# Generating new music...
# Generated MIDI saved as: task1.mid
# Total events: 1000
# Duration: ~226.7 beats
# Music generation completed!
